# %% [markdown]
# # Exercise 2 - CNNs, ResNets and LR-Scheduling

# %% [markdown]
#  * Deep Learning for Computer Vision – Winter Term 2025/26
#  * Lecture by: Constantin Pape
#  * Organizers: Anwai Archit, Sushmita Nair
#  * Tutors: Azhar Akhmetova, Benjamin Eckhardt, Carolin Teuber, Luca Freckmann, Marei Freitag, Oleg Bakumenko, Sarah Muth
#  * Due date: **Tuesday, Nov 25, before 10:00**

# %% [markdown]
# ### Time required to solve this exercise sheet
# **As you will train a large number of models on this exercise sheet, model training will require an increased amount of time. So we recommend to start working on this sheet early.**

# %% [markdown]
# ### Topics
#
# In this exercise sheet, you will:
# - work again with CIFAR-10
# - implement a 1-layer CNN
# - compare MLP and CNN
# - vary architecture to improve model performance
# - implement a ResNet for CIFAR-10
# - learn about learning rate scheduling
#
# *We are looking forward to seeing your solutions! Have fun!*

# %% [markdown]
# ## IMPORTANT SUBMISSION INSTRUCTIONS
#
# - **You need to answer all questions in written form!**
# - When you've completed the exercise, download the notebook and rename it to `<surname1>_<surname2>_<surname3>.ipynb`
# - Only submit the Jupyter Notebook (.ipynb file). No other file is required.
#     - Upload it on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission of Homework 2` -> `Tutorial X` (where X is the tutorial you are assigned to).
# - Make only one submission of the exercise per group.
# - The deadline is strict.
# - You have to present the exercise in the tutorials. We have a high ratio of students to tutors, so please decide which team member presents which part beforehand
#
# Implementation:
# - Do not change the cells which are marked as `DO NOT CHANGE`, similarly write your solution into the cells marked with TODOs for the questions asked.

# %% [markdown]
# ### How to work on the exercise?
# You will need access to a machine with a GPU to properly work on the exercises. We recommend using [JupyterHPC](https://jupyter.hpc.gwdg.de/), which offers convenient access to a GPU. We have provided access to all the dependencies that we need preinstalled ([here](https://docs.google.com/document/d/1frgBvU9ZRcR7PkMqOuK5eTj5RphZBmjz_i6OgA1DVwE/edit?usp=sharing) are the initial steps and step-by-step guide to get started with working on JupyterHPC).
#
# In addition, another recommended solution would be using [Kaggle](https://www.kaggle.com/), which also offers convenient access to a GPU and has all the dependencies that we need preinstalled ([here](https://gist.github.com/anwai98/444d3ff11c1365f2c610579d5df0830b) are the initial steps to work the Kaggle Notebooks). You can load this notebook on Kaggle via `File` -> `Import Notebook` -> `Browse Files` and `Import`.

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau, ExponentialLR, StepLR
import torchvision
from torchvision import datasets, transforms, models
import fastprogress
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import time
from pathlib import Path
import os
import sys
import time
import importlib

# %%
project_path = Path(os.environ.get("PROJECT")).resolve()

# %% [markdown]
# ## 1. Setup
#
# You can use the functions to grab the data, split the sets, create the dataloaders and plot results, etc. given to you at exercise sheet 1.
#
# It is good practice to store functions that are constantly needed again in a separate file such that instead of copy-pasting the cells into each exercise notebook, you can use the python file containing the functions and import it in the notebooks.
#
# If you use JupyterHPC (recommended), the file with functions from exercise 1 is already uploaded to `$PROJECT/utils/setup.py`.
#
# Hint:
# To load a custom script from path you can use `importlib` module together with this code:
# ```python
# spec = importlib.util.spec_from_file_location("module_name", module_path)
# s = importlib.util.module_from_spec(spec) # we call it s for setup
# spec.loader.exec_module(s)
# ```
# and validate it for example by getting the device: `s.get_device()`.
#
# Alternatively you can copy the file to your workspace using terminal `cp $PROJECT/utils/setup.py $HOME/your/notebook/location/` and import as usuall:
#
# `import setup as s`

# %% [markdown]
# #### For Kaggle users
# If you work with Kaggle you have to mount the drive first and create a path to your python module or download the file from drive.
# Create a file named `setup.py` and copy all the necessary functions to it, e.g. dataset preparation and training.
#
# Alternativelly you can download this file to your workspace from drive and import it on this notebook.
# File URL is https://drive.google.com/file/d/1066jDUxp8fXwdcNGj8h0CWJA0KNLpvKk/view?usp=share_link
#
# Hint:
# For download you can use the package `gdown`
#
# ```python
# !conda install -y gdown
# !gdown <file_id>
# ```
#
# where, `file_id` is "1066jDUxp8fXwdcNGj8h0CWJA0KNLpvKk"
#
# Then, setup.py should be added to your workspace and you can import it as usual module `import setup as s`

# %%
# %cp $PROJECT/utils/setup.py ./

# %% [markdown]
# ## 2. Load dataset, create dataloader, etc.
#
# #### **TODO**
# Call the functions of `setup.py` to instantiate the train-, test- and validation CIFAR10 datasets along with their dataloaders.

# %%
# TODO: Define device
import setup as s
device = s.get_device()
# Out:
# cuda available: True; cudnn available: True; num devices: 1
# Using device NVIDIA A100-SXM4-80GB MIG 1g.10gb

# %%
data_dir = Path(project_path, "data", "Ex1")
batch_size = 512

# TODO: Grab data, generate split and initialize data loaders
trainset, testset = s.grab_data(data_dir)
trainset, valset = s.generate_train_val_data_split(trainset)
trainloader, valloader, testloader = s.init_data_loaders(trainset, valset, testset)

# %% [markdown]
# #### **TODO**
# Define the loss function. We use the cross entropy loss again.

# %%
# TODO: Define loss function
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# ## 3. Simple 1-layer CNN model

# %% [markdown]
# ### **TODO**
# - Define the model.
#
# The first step to training a model is defining its architecture.
# Define a sequential model with following structure:
# *   Convolutional layer with 32 filters, kernel size of 5*5 and stride of 1.
# *   Max Pooling layer with kernel size of 2*2 and default stride.
# *   ReLU Activation Layers.
# *   Linear layer with output of 512.
# *   ReLU Activation Layers.
# *   A linear layer with output of 10.

# %% [markdown]
# ![photo5323590519076531812.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Questions**
#
# - What are the input dimensions?
#     - A: 32x32x3, as the images in CIFAR-10 are
# - What are the dimensions of the feature maps?
#     - A: 28x28 after the convolution with the 5x5 filters, because they shrink by k-1 pixels.
# - What are the dimensions after pooling?
#     - A: 14x14
# - What is the size of each input (i.e value of `in_features`) to the first fully connected linear layer?
#     - A: 14x14x32(number of filters) = 6272
# - What is the number of parameters for conv_1?
#     - A: Filters x Kernel Size x Channels= 32x5x5x3 = 2400

# %% [markdown]
# **Your answers here**

# %%
# TODO: Define model
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        #empty layers
        layers = []
        
        layers.append(nn.Conv2d(3,32,5))
        
        layers.append(nn.MaxPool2d(2))

        layers.append(nn.ReLU())

        layers.append(nn.Flatten())
        layers.append(nn.Linear(32*14*14, 512))

        layers.append(nn.ReLU())

        layers.append(nn.Linear(512, 10))

        self.layers = nn.Sequential(*layers)
    
    def forward(self, x):
        x_preds = self.layers(x)
        return x_preds

# %% [markdown]
# #### **TODO**
#
# - Train the model for 10 epochs. Try lr=0.001 (can be changed to suit other design choices you make)
# - Plot the results of accuracy and loss as you did in exercise sheet 1.

# %%
# TODO: Train and plot
model = CNN()
model.to(device)

num_epochs = 10
lr=0.001
optimizer = optim.Adam(model.parameters(), lr)

trainloss, valloss, trainacc, valacc, confmat = s.run_training(model, optimizer, loss_fn, device, 
                                                      num_epochs, trainloader, valloader)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 105 seconds.

# %%
s.plot(
    title = "Training Loss vs Epoch",
    label = "Loss",
    train_results = trainloss,
    val_results = valloss
)
s.plot(
    title = "Training Accuracy vs Epoch",
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc
)

# %% [markdown]
# #### **TODO**
# Compare results to the MLP models you trained in Exercise 1. What can you observe?

# %% [markdown]
# **Your answers here**
# We can see that the loss started off lower in the first epoch in our CNN. The total loss of the training results was also lower in our 10th epoch than in the 100th of the MLP
#
# The accuracy was also better in ours in the first epoch, and better than the MLP in the final one.

# %% [markdown]
# **For your reference, below is the loss and accuracy plots of an MLP model trained in Exercise sheet 1:**

# %% [markdown]
# ![ex2mlpperf.png](data:image/png;base64,...)

# %% [markdown]
# #### **TODO**
# Train longer (ca. 60 epochs), plot again.

# %%
# TODO: Train and plot
num_epochs = 60
trainloss, valloss, trainacc, valacc, confmat = s.run_training(model, optimizer, loss_fn, device, 
                                                      num_epochs, trainloader, valloader)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 1270 seconds.

# %%
s.plot(
    title = "Training Loss vs Epoch",
    label = "Loss",
    train_results = trainloss,
    val_results = valloss
)
s.plot(
    title = "Training Accuracy vs Epoch",
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc
)

# %% [markdown]
# #### **Questions**
# - Why is that not an optimal model?
# - What could be improved?

# %% [markdown]
# **Your answers here**
#
# The model obviously overfits, as you can see with the accuracy reaching almost 1 at around epoch 20 on the training accuracy
#
# We could improve it by adding more

# %% [markdown]
# ## 4. CNN model with more convolutional layers

# %% [markdown]
# #### **TODO**
# Define the architecture using the following information:
#
#
#
# ![model2_4.png](data:image/png;base64,...)

# %% [markdown]
# *   Convolutional layer 1: with 32 filters, kernel size of 3*3 and padding 1.
# *   Batchnorm and ReLU layers
# *   Convolutional layer 2: with 64 filters, kernel size of 3*3 and padding 1.
# *   ReLU Activation layer
# *   Max pooling with kernel size of 2*2
# *   Convolutional layer 3: with 128 filters, kernel size of 3*3 and padding 1.
# *   Batchnorm and ReLU layers
# *   Convolutional layer 4: with 128 filters, kernel size of 3*3 and padding 1.
# *   ReLU Activation layer
# *   Average pooling with kernel size 16*16
# *   Fully connected layer

# %% [markdown]
# #### **Questions**
#
# - Padding is used in the convolutional layers. What does that mean, which variants exist and how does it influence the dimensions of the feature maps?
# - What does padding=1 mean in the case of the network displayed above?
# - What are the dimensions of the feature maps after the 1. conv layer?
# - What are the dimensions of the feature maps after the 2. conv layer?
# - What ist the receptive field size after the first two convolutions?
# - What is the value for the in_features for the fully-connected layer?
# - What is the number of parameters of *Conv Layer block 1*?

# %% [markdown]
# **Your answers here**

# %% [markdown]
# 1. Adding padding to a picture, means adjusting the size of a picture before applying convolution with a kernel to increase the size of the output and thus the reflecting features of the feature maps. There exists Zero Padding, Reflective Padding, Valid padding, same padding, full padding.
# 2. We increase the size of the input by 1, e.g.: for 32x32 we get 33x33
# 3. ((32-3+2*1)/1) + 1 = 31
# 4. ((31-3+2*1)/1) + 1 = 31
# 5. 1+((3-1)+(3-1)) = 5
# 6. The average pooling with kernel size 16 x 16 after the 4th layer reduces the spatial dimension to 1 x 1. This results in only depth, so the number of channels. The last convolutional layer has 128 filters. So the depth of the feature map is 128. For the fully-conected layer, the feature map is flattened so: 1 x 1 x 128
# 7. 3*3*3*32 + 32 = 864 + 32 = 896, Batch Normalization = 32 + 32 = 64
# 3 * 3 * 32 * 64 + 64 = 18432 + 64 = 18496
# Total number of parameters of Conv Layer block 1 is: 896 + 64 + 18496 = 19456

# %%
# TODO: Define model 2

class CNN2(nn.Module):
    def __init__(self):
        super().__init__()
        
        # Define layers
        layers = []
        # Convolutional layer 1: with 32 filters, kernel size of 3*3 and padding 1.
        layers.append(nn.Conv2d(3, 32, 3, padding=1)) # M = N + 2p - k +1 = 32 + 2 - 3 + 1 = 32

        # Batchnorm and ReLU layers
        layers.append(nn.BatchNorm2d(32))
        layers.append(nn.ReLU())
        
        # Convolutional layer 2: with 64 filters, kernel size of 3*3 and padding 1.
        layers.append(nn.Conv2d(32, 64, 3, padding=1)) # M = N + 2p - k +1 = 32 + 2 - 3 + 1 = 32
        
        # ReLU Activation layer
        layers.append(nn.ReLU())
        
        # Max pooling with kernel size of 2*2
        layers.append(nn.MaxPool2d(2)) # N = 32/2 = 16
        
        # Convolutional layer 3: with 128 filters, kernel size of 3*3 and padding 1.
        layers.append(nn.Conv2d(64, 128, 3, padding=1)) # M = N + 2p - k +1 = 16 + 2 - 3 + 1 = 16
        
        # Batchnorm and ReLU layers
        layers.append(nn.BatchNorm2d(128))
        layers.append(nn.ReLU())
        
        # Convolutional layer 4: with 128 filters, kernel size of 3*3 and padding 1.
        layers.append(nn.Conv2d(128, 128, 3, padding=1)) # M = N + 2p - k +1 = 16 + 2 - 3 + 1 = 16
        
        # ReLU Activation layer
        layers.append(nn.ReLU())
        
        # Average pooling with kernel size 16*16
        layers.append(nn.AvgPool2d(16)) # M = 16 / 16 = 1
        
        # Fully connected layer
        layers.append(nn.Flatten())
        layers.append(nn.Linear(128 * 1 * 1, 10))

        # Create sequential model
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        x_predictions = self.layers(x)

        # Return the predicted output
        return x_predictions

# %% [markdown]
# #### **TODO**
#
# - train the new net (30 epochs, try lr=0.1 or change as necessary), plot the results, and compare the results to the 1-layer CNN
# - explain why you observe these results

# %%
# TODO: Train and plot
model2 = CNN2()
model2.to(device)

num_epochs = 30
lr = 0.01
optimizer = optim.Adam(model2.parameters(), lr)
trainloss, valloss, trainacc, valacc, confmat = s.run_training(model2, optimizer, loss_fn, device, num_epochs, trainloader, valloader, verbose=True)

torch.save(model2.state_dict(), './model2.pth')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 0, train loss: 2.07, val loss: 2.04, train acc: 0.263, val acc 0.276<p>Epoch 1, train loss: 1.62, val loss: 1.80, train acc: 0.386, val acc 0.344<p>Epoch 2, train loss: 1.44, val loss: 1.51, train acc: 0.467, val acc 0.466<p>Epoch 3, train loss: 1.30, val loss: 1.84, train acc: 0.530, val acc 0.399<p>Epoch 4, train loss: 1.20, val loss: 1.32, train acc: 0.569, val acc 0.530<p>Epoch 5, train loss: 1.12, val loss: 1.78, train acc: 0.597, val acc 0.453<p>Epoch 6, train loss: 1.08, val loss: 1.59, train acc: 0.616, val acc 0.479<p>Epoch 7, train loss: 1.03, val loss: 1.44, train acc: 0.633, val acc 0.519<p>Epoch 8, train loss: 0.95, val loss: 1.41, train acc: 0.660, val acc 0.520<p>Epoch 9, train loss: 0.91, val loss: 1.30, train acc: 0.673, val acc 0.553<p>Epoch 10, train loss: 0.87, val loss: 1.69, train acc: 0.690, val acc 0.493<p>Epoch 11, train loss: 0.87, val loss: 1.20, train acc: 0.694, val acc 0.586<p>Epoch 12, train loss: 0.83, val loss: 1.00, train acc: 0.706, val acc 0.656<p>Epoch 13, train loss: 0.78, val loss: 0.99, train acc: 0.724, val acc 0.658<p>Epoch 14, train loss: 0.78, val loss: 0.98, train acc: 0.729, val acc 0.642<p>Epoch 15, train loss: 0.74, val loss: 1.09, train acc: 0.737, val acc 0.631<p>Epoch 16, train loss: 0.73, val loss: 1.37, train acc: 0.744, val acc 0.576<p>Epoch 17, train loss: 0.70, val loss: 0.93, train acc: 0.753, val acc 0.698<p>Epoch 18, train loss: 0.68, val loss: 1.21, train acc: 0.761, val acc 0.604<p>Epoch 19, train loss: 0.67, val loss: 1.15, train acc: 0.764, val acc 0.647<p>Epoch 20, train loss: 0.63, val loss: 1.29, train acc: 0.778, val acc 0.588<p>Epoch 21, train loss: 0.62, val loss: 0.95, train acc: 0.780, val acc 0.687<p>Epoch 22, train loss: 0.61, val loss: 0.79, train acc: 0.787, val acc 0.722<p>Epoch 23, train loss: 0.60, val loss: 1.05, train acc: 0.791, val acc 0.660<p>Epoch 24, train loss: 0.58, val loss: 1.10, train acc: 0.797, val acc 0.648<p>Epoch 25, train loss: 0.56, val loss: 0.95, train acc: 0.803, val acc 0.686<p>Epoch 26, train loss: 0.54, val loss: 0.82, train acc: 0.808, val acc 0.732<p>Epoch 27, train loss: 0.53, val loss: 1.16, train acc: 0.815, val acc 0.651<p>Epoch 28, train loss: 0.53, val loss: 1.23, train acc: 0.817, val acc 0.612<p>Epoch 29, train loss: 0.54, val loss: 0.82, train acc: 0.809, val acc 0.718
# Finished training after 434 seconds.

# %%
title = "Training Accuracy vs Epoch"
s.plot(
    title = title,
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc)

title = "Training Loss vs Epoch"
s.plot(
    title = title,
    label = "Loss",
    train_results = trainloss,
    val_results = valloss)

# %% [markdown]
# ## 5. ResNet architecture
#
# "*Deeper neural networks are more difficult to train.  We present a residual learning framework to ease the training of networks that are substantially deeper than those used previously.*" [ https://arxiv.org/pdf/1512.03385.pdf]
#
# That was the intention of He et al. to develop residual networks.
#
# A ResNet is built of blocks which are called the *Residual Blocks*.
# A residual block uses *skip connections* - shortCuts — to jump over some layers to skip some activations.
# The Resnet skips connections via addition.
#
# ![resblock.png](data:image/png;base64,...)

# %% [markdown]
# #### **Questions**
# - Which problems do using skip connections solve?
# - Why is a residual network called residual?

# %% [markdown]
# **Your answers here**

# %% [markdown]
# #### **TODO**
# - write a class **ResidualBlock(nn.Module)** where you define the blocks used in the ResNet
# - write a class **ResNet(nn.Module)** where you define the model
# - Train the model and plot results
# - Train another model by disable residual connections and compare performance

# %% [markdown]
# ![resnet_copy.jpg](attachment:469eb159-8c38-403c-af7c-21fd87465853.jpg)

# %% [markdown]
# **Hints**
#
# - The downsampling in this ResNet happens between layer 1 and layer 2. In this step, the channel size is increased (32 -> 64) and the image resolution is downsampled by strided convolution (stride=2 in the Conv2d layers).
# - For the adding part, the dimensions obviously have to be the same. This is accomplished by using stride=2 in the first Conv2d layer of the block while the second layer does not change the dimensions.
# - The average-pooling layer has kernel size 7.
# - For you to ensure everything works fine, here are the shapes in the form [(batchsize), x, y, channel] where I discard batchsize, because it does not change.
# 32x32x3 -> conv 7x7 -> 14x14x32 -> layer 1 -> 14x14x32 -> layer2 -> 7x7x64 -> avpool(7) -> 1x1x64 -> linear(64, 10)

# %%
# TODO: Write a class ResidualBlock(nn.Module) where you define the blocks used in the ResNet
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample = False, disable_residual = False):
        super().__init__()
        
        # Define layers
        layers = []

        # Conv 1
        self.stride = 2 if downsample else 1
            
        layers.append(nn.Conv2d(in_channels, out_channels, 3, stride=self.stride, padding=1))

        
        # Batchnorm and ReLU layers
        layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.ReLU())

        # Conv 2
        layers.append(nn.Conv2d(out_channels, out_channels, 3, stride = 1, padding=1))

        # Batchnorm
        layers.append(nn.BatchNorm2d(out_channels))
        
        # Create sequential model
        self.layers = nn.Sequential(*layers)
        
        
        self.downsample = None
        if in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv2d(
                    in_channels, 
                    out_channels, 
                    kernel_size=(3, 3), 
                    stride = 2,
                    padding=1, 
                    bias=False
                ),
                nn.BatchNorm2d(out_channels)
            )
            
        self.disable_residual = disable_residual
        
    def forward(self, x):
        """Compute model predictions.

        Args:
            x (torch.Tensor, shape (batchsize, num_channels, x, y)): Tensor of
                batch of input images

        Returns:
            torch.Tensor, shape (batchsize, num_classes): Tensor of model
                predictions
        """
        
        identity = self.downsample(x) if self.downsample else x
        
        x_predictions = self.layers(x)
        # Add residual ReLU
        if not self.disable_residual:
            x_predictions = x_predictions + identity
            
        x_predictions = torch.relu(x_predictions)

        # Return the predicted output
        return x_predictions

# %%
# TODO: Write a class ResNet(nn.Module) where you define the model
# TODO: Write a class ResNet(nn.Module) where you define the model
class ResNet(nn.Module):
    def __init__(self, disable_residual = False):
        super().__init__()
        
        # Define layers
        layers = []

        # Conv 7x7, s=2, p=1, 32 filters
        layers.append(nn.Conv2d(3,32,7, stride=2, padding=1)) # M = (32+2+7)/2 + 1 = 14 
        
        # Batchnorm and ReLU layers
        layers.append(nn.BatchNorm2d(32))
        layers.append(nn.ReLU())

        # Layer 1
        layers.append(ResidualBlock(32,32, disable_residual=disable_residual))
        layers.append(ResidualBlock(32,32, disable_residual=disable_residual))
        
        # Layer 2
        layers.append(ResidualBlock(32,64,downsample=True, disable_residual=disable_residual))
        layers.append(ResidualBlock(64,64, disable_residual=disable_residual))
        
        # Average pooling with kernel size 7*7
        layers.append(nn.AvgPool2d(7)) # M =  / 7 = 1
        
        # Fully connected layer
        layers.append(nn.Flatten())
        layers.append(nn.Linear(64, 10))
        
        # Create sequential model
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        """Compute model predictions.

        Args:
            x (torch.Tensor, shape (batchsize, num_channels, x, y)): Tensor of
                batch of input images

        Returns:
            torch.Tensor, shape (batchsize, num_classes): Tensor of model
                predictions
        """
        x_predictions = self.layers(x)

        # Return the predicted output
        return x_predictions

# %%
# TODO: Train ResNet using the architecture laid out in the comments and figures above. Plot loss and accuracy for training and validation set.
resnet_model = ResNet()
resnet_model.to(device)

num_epochs = 100
lr = 0.01
optimizer = optim.Adam(resnet_model.parameters(), lr)
early_stopper = s.EarlyStopper(patience = 10)
trainloss, valloss, trainacc, valacc, confmat = s.run_training(resnet_model, optimizer, loss_fn, device, num_epochs, trainloader, valloader, early_stopper=early_stopper,verbose=True)

torch.save(resnet_model.state_dict(), './resnet_model.pth')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='62' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       62.00% [62/100 12:07&lt;07:25]
#     </div>
#
# Epoch 0, train loss: 1.90, val loss: 1.81, train acc: 0.285, val acc 0.335<p>Epoch 1, train loss: 1.58, val loss: 1.73, train acc: 0.411, val acc 0.388<p>Epoch 2, train loss: 1.44, val loss: 1.49, train acc: 0.466, val acc 0.455<p>Epoch 3, train loss: 1.30, val loss: 1.55, train acc: 0.521, val acc 0.466<p>Epoch 4, train loss: 1.20, val loss: 1.36, train acc: 0.567, val acc 0.512<p>Epoch 5, train loss: 1.10, val loss: 1.29, train acc: 0.604, val acc 0.539<p>Epoch 6, train loss: 1.01, val loss: 1.38, train acc: 0.637, val acc 0.523<p>Epoch 7, train loss: 0.98, val loss: 1.28, train acc: 0.653, val acc 0.556<p>Epoch 8, train loss: 0.90, val loss: 1.14, train acc: 0.678, val acc 0.602<p>Epoch 9, train loss: 0.83, val loss: 1.11, train acc: 0.707, val acc 0.630<p>Epoch 10, train loss: 0.81, val loss: 1.01, train acc: 0.713, val acc 0.640<p>Epoch 11, train loss: 0.73, val loss: 0.91, train acc: 0.744, val acc 0.682<p>Epoch 12, train loss: 0.69, val loss: 0.99, train acc: 0.755, val acc 0.662<p>Epoch 13, train loss: 0.65, val loss: 0.93, train acc: 0.772, val acc 0.686<p>Epoch 14, train loss: 0.60, val loss: 0.87, train acc: 0.787, val acc 0.705<p>Epoch 15, train loss: 0.54, val loss: 0.91, train acc: 0.808, val acc 0.714<p>Epoch 16, train loss: 0.50, val loss: 0.99, train acc: 0.826, val acc 0.692<p>Epoch 17, train loss: 0.49, val loss: 0.92, train acc: 0.827, val acc 0.701<p>Epoch 18, train loss: 0.43, val loss: 0.91, train acc: 0.851, val acc 0.723<p>Epoch 19, train loss: 0.39, val loss: 1.23, train acc: 0.866, val acc 0.659<p>Epoch 20, train loss: 0.41, val loss: 0.91, train acc: 0.854, val acc 0.720<p>Epoch 21, train loss: 0.38, val loss: 0.85, train acc: 0.867, val acc 0.740<p>Epoch 22, train loss: 0.31, val loss: 0.99, train acc: 0.892, val acc 0.712<p>Epoch 23, train loss: 0.32, val loss: 0.99, train acc: 0.886, val acc 0.709<p>Epoch 24, train loss: 0.26, val loss: 1.03, train acc: 0.909, val acc 0.719<p>Epoch 25, train loss: 0.21, val loss: 1.08, train acc: 0.927, val acc 0.723<p>Epoch 26, train loss: 0.21, val loss: 1.14, train acc: 0.923, val acc 0.715<p>Epoch 27, train loss: 0.21, val loss: 1.16, train acc: 0.927, val acc 0.709<p>Epoch 28, train loss: 0.27, val loss: 1.05, train acc: 0.902, val acc 0.717<p>Epoch 29, train loss: 0.19, val loss: 0.97, train acc: 0.935, val acc 0.744<p>Epoch 30, train loss: 0.12, val loss: 1.06, train acc: 0.963, val acc 0.736<p>Epoch 31, train loss: 0.10, val loss: 1.12, train acc: 0.969, val acc 0.737<p>Epoch 32, train loss: 0.10, val loss: 1.27, train acc: 0.968, val acc 0.731<p>Epoch 33, train loss: 0.10, val loss: 1.31, train acc: 0.964, val acc 0.730<p>Epoch 34, train loss: 0.10, val loss: 1.33, train acc: 0.964, val acc 0.733<p>Epoch 35, train loss: 0.10, val loss: 1.51, train acc: 0.964, val acc 0.707<p>Epoch 36, train loss: 0.07, val loss: 1.28, train acc: 0.974, val acc 0.737<p>Epoch 37, train loss: 0.04, val loss: 1.27, train acc: 0.990, val acc 0.749<p>Epoch 38, train loss: 0.05, val loss: 1.40, train acc: 0.983, val acc 0.737<p>Epoch 39, train loss: 0.06, val loss: 1.42, train acc: 0.980, val acc 0.740<p>Epoch 40, train loss: 0.08, val loss: 1.70, train acc: 0.972, val acc 0.701<p>Epoch 41, train loss: 0.13, val loss: 1.52, train acc: 0.952, val acc 0.721<p>Epoch 42, train loss: 0.10, val loss: 1.39, train acc: 0.965, val acc 0.734<p>Epoch 43, train loss: 0.09, val loss: 1.41, train acc: 0.966, val acc 0.738<p>Epoch 44, train loss: 0.05, val loss: 1.36, train acc: 0.984, val acc 0.747<p>Epoch 45, train loss: 0.02, val loss: 1.36, train acc: 0.994, val acc 0.752<p>Epoch 46, train loss: 0.01, val loss: 1.35, train acc: 0.997, val acc 0.760<p>Epoch 47, train loss: 0.00, val loss: 1.37, train acc: 1.000, val acc 0.760<p>Epoch 48, train loss: 0.00, val loss: 1.38, train acc: 1.000, val acc 0.761<p>Epoch 49, train loss: 0.00, val loss: 1.41, train acc: 1.000, val acc 0.760<p>Epoch 50, train loss: 0.00, val loss: 1.40, train acc: 1.000, val acc 0.761<p>Epoch 51, train loss: 0.00, val  ...
#
#     <div>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:04&lt;00:00]
#     </div>
# early stopping
# Finished training after 752 seconds.

# %%
title = "Training Accuracy vs Epoch"
s.plot(
    title = title,
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc)

title = "Training Loss vs Epoch"
s.plot(
    title = title,
    label = "Loss",
    train_results = trainloss,
    val_results = valloss)

# %%
# TODO: Train another model by disabling all residual connections. Plot loss and accuracy curves for training and validation set.

# %% [markdown]
# #### **Questions**
# - Does using residual connections result in better performance in this exercise? If yes, why? If not, when would the benefit of using ResNet be most visible?
# - In deeper networks, how would you expect residual blocks to influence training time? why?
# - Compare the performance and training time of your ResNet with the CNNs you trained in the previous section.

# %% [markdown]
# **Your answers here**

# %% [markdown]
# ## 6. Explore Learning Rate Scheduling
#
# Learning rate scheduling is a mechanism to adjust the learning rate.
#
# *`torch.optim.lr_scheduler`* provides several methods based on the number of epochs. Learning rate scheduling should be applied after optimizer’s update.

# %% [markdown]
# #### **TODO**
# - change run_training and extend to use scheduler for learning rate
# - use `StepLR` (https://pytorch.org/docs/stable/optim.html), use the ResNet, train for 10 epochs. Start with a learning rate of 0.1.

# %% [markdown]
# #### **Questions**
#
# - Try step size 1, gamma 0.1
#     - How does it change the learning rate?
#     - what do you observe regarding performance?
# - Try step size 1, gamma 0.9, what do you observe?
#     - How does it change the learning rate?
#     - what do you observe regarding performance?
# - What can you conclude of this experiment regarding the synergy of step size and gamma to get a good schedule?

# %% [markdown]
# **Your answers here**
# 1.1 each episode the lr gets multipleid by 0.1
# 1.2 the performance is not great, the learning rate diominishes to fast the model stops to train
#
# 2.1 same but * 0.9
# 2.2 perf greatly improves over the 0.1 since the lr doesnt diminish too fast.

# %%
# TODO: Change run_training (you can copy the code from setup.py here and create a new method here
# or just change/create a new method it in the python file)
import setup
def run_training(
    model,
    optimizer,
    loss_function,
    device,
    num_epochs,
    train_dataloader,
    val_dataloader,
    early_stopper=None,
    verbose=False,
    scheduler=None,
):
    """Run model training.

    Args:
        model (nn.Module): Torch model to train
        optimizer: Torch optimizer object
        loss_fn: Torch loss function for training
        device (torch.device): Torch device to use for training
        num_epochs (int): Max. number of epochs to train
        train_dataloader (DataLoader): Torch DataLoader object to load the
            training data
        val_dataloader (DataLoader): Torch DataLoader object to load the
            validation data
        early_stopper (EarlyStopper, optional): If passed, model will be trained
            with early stopping. Defaults to None.
        verbose (bool, optional): Print information about model training.
            Defaults to False.

    Returns:
        list, list, list, list, torch.Tensor shape (10,10): Return list of train
            losses, validation losses, train accuracies, validation accuracies
            per epoch and the confusion matrix evaluated in the last epoch.
    """
    start_time = time.time()
    master_bar = fastprogress.master_bar(range(num_epochs))
    train_losses, val_losses, train_accs, val_accs = [], [], [], []

    for epoch in master_bar:
        # Train the model
        epoch_train_loss, epoch_train_acc = s.train(train_dataloader, optimizer, model, loss_function, device, master_bar)
        # Validate the model
        epoch_val_loss, epoch_val_acc, confusion_matrix = s.validate(
            val_dataloader, model, loss_function, device, master_bar
        )

        # Save loss and acc for plotting
        train_losses.append(epoch_train_loss)
        val_losses.append(epoch_val_loss)
        train_accs.append(epoch_train_acc)
        val_accs.append(epoch_val_acc)

        if verbose:
            master_bar.write(
                f"Epoch {epoch}, train loss: {epoch_train_loss:.2f}, val loss: {epoch_val_loss:.2f}, train acc: {epoch_train_acc:.3f}, val acc {epoch_val_acc:.3f}"
            )

        if early_stopper:
            early_stopper.update(epoch_val_acc, model)
            if early_stopper.early_stop:
                model = early_stopper.load_checkpoint(model)
                print("early stopping")
                break
        if scheduler:
            scheduler.step()
            # END OF YOUR CODE #

    time_elapsed = np.round(time.time() - start_time, 0).astype(int)
    print(f"Finished training after {time_elapsed} seconds.")
    return train_losses, val_losses, train_accs, val_accs, confusion_matrix

# %%
# TODO: Train and plot with step size 1, gamma 0.1
resnet_model = ResNet()
resnet_model.to(device)

num_epochs = 10
lr = 0.1
optimizer = optim.Adam(resnet_model.parameters(), lr)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)

early_stopper = s.EarlyStopper(patience = 10)
trainloss, valloss, trainacc, valacc, confmat = run_training(resnet_model, optimizer, loss_fn, device, num_epochs, trainloader, valloader, early_stopper=early_stopper,verbose=True,scheduler=scheduler)

torch.save(resnet_model.state_dict(), './resnet_model_steplr1.pth')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 0, train loss: 2.39, val loss: 2.43, train acc: 0.139, val acc 0.186<p>Epoch 1, train loss: 2.09, val loss: 2.08, train acc: 0.210, val acc 0.215<p>Epoch 2, train loss: 2.07, val loss: 2.07, train acc: 0.215, val acc 0.214<p>Epoch 3, train loss: 2.07, val loss: 2.07, train acc: 0.214, val acc 0.214<p>Epoch 4, train loss: 2.07, val loss: 2.07, train acc: 0.216, val acc 0.216<p>Epoch 5, train loss: 2.07, val loss: 2.07, train acc: 0.214, val acc 0.215<p>Epoch 6, train loss: 2.07, val loss: 2.07, train acc: 0.214, val acc 0.214<p>Epoch 7, train loss: 2.07, val loss: 2.07, train acc: 0.215, val acc 0.215<p>Epoch 8, train loss: 2.07, val loss: 2.07, train acc: 0.214, val acc 0.215<p>Epoch 9, train loss: 2.07, val loss: 2.07, train acc: 0.214, val acc 0.216
# Finished training after 241 seconds.

# %%
title = "Training Accuracy vs Epoch"
s.plot(
    title = title,
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc)

title = "Training Loss vs Epoch"
s.plot(
    title = title,
    label = "Loss",
    train_results = trainloss,
    val_results = valloss)

# %%
# TODO: Train and plot with step size 1, gamma 0.9
resnet_model = ResNet()
resnet_model.to(device)

num_epochs = 10
lr = 0.1
optimizer = optim.Adam(resnet_model.parameters(), lr)
scheduler = StepLR(optimizer, step_size=1, gamma=0.9)

early_stopper = s.EarlyStopper(patience = 10)
trainloss, valloss, trainacc, valacc, confmat = run_training(resnet_model, optimizer, loss_fn, device, num_epochs, trainloader, valloader, early_stopper=early_stopper,verbose=True,scheduler=scheduler)

torch.save(resnet_model.state_dict(), './resnet_model_steplr2.pth')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 0, train loss: 2.35, val loss: 2.25, train acc: 0.161, val acc 0.182<p>Epoch 1, train loss: 1.93, val loss: 2.74, train acc: 0.238, val acc 0.185<p>Epoch 2, train loss: 1.79, val loss: 1.79, train acc: 0.309, val acc 0.319<p>Epoch 3, train loss: 1.66, val loss: 1.74, train acc: 0.364, val acc 0.354<p>Epoch 4, train loss: 1.58, val loss: 1.70, train acc: 0.400, val acc 0.362<p>Epoch 5, train loss: 1.48, val loss: 1.56, train acc: 0.446, val acc 0.402<p>Epoch 6, train loss: 1.41, val loss: 1.52, train acc: 0.476, val acc 0.451<p>Epoch 7, train loss: 1.34, val loss: 1.60, train acc: 0.503, val acc 0.429<p>Epoch 8, train loss: 1.30, val loss: 1.36, train acc: 0.520, val acc 0.500<p>Epoch 9, train loss: 1.25, val loss: 1.42, train acc: 0.537, val acc 0.479
# Finished training after 240 seconds.

# %%
title = "Training Accuracy vs Epoch"
s.plot(
    title = title,
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc)

title = "Training Loss vs Epoch"
s.plot(
    title = title,
    label = "Loss",
    train_results = trainloss,
    val_results = valloss)

# %% [markdown]
# #### **TODO**
#
# Use step size 15, gamma 0.1. Train for 30 epochs.

# %%
# TODO: Train and plot with step size 15, gamma 0.1, 30 epochs.
resnet_model = ResNet()
resnet_model.to(device)

num_epochs = 30
lr = 0.1
optimizer = optim.Adam(resnet_model.parameters(), lr)
scheduler = StepLR(optimizer, step_size=15, gamma=0.1)

early_stopper = None
trainloss, valloss, trainacc, valacc, confmat = run_training(resnet_model, optimizer, loss_fn, device, num_epochs, trainloader, valloader, early_stopper=early_stopper,verbose=True,scheduler=scheduler)

torch.save(resnet_model.state_dict(), './resnet_model_steplr3.pth')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Epoch 0, train loss: 2.40, val loss: 2.19, train acc: 0.132, val acc 0.200<p>Epoch 1, train loss: 2.05, val loss: 2.42, train acc: 0.208, val acc 0.156<p>Epoch 2, train loss: 1.90, val loss: 2.06, train acc: 0.254, val acc 0.233<p>Epoch 3, train loss: 1.78, val loss: 2.30, train acc: 0.310, val acc 0.211<p>Epoch 4, train loss: 1.71, val loss: 1.92, train acc: 0.344, val acc 0.270<p>Epoch 5, train loss: 1.64, val loss: 2.28, train acc: 0.375, val acc 0.221<p>Epoch 6, train loss: 1.57, val loss: 1.81, train acc: 0.404, val acc 0.334<p>Epoch 7, train loss: 1.51, val loss: 1.64, train acc: 0.433, val acc 0.406<p>Epoch 8, train loss: 1.47, val loss: 1.52, train acc: 0.453, val acc 0.431<p>Epoch 9, train loss: 1.42, val loss: 1.44, train acc: 0.478, val acc 0.465<p>Epoch 10, train loss: 1.36, val loss: 1.62, train acc: 0.499, val acc 0.425<p>Epoch 11, train loss: 1.32, val loss: 1.76, train acc: 0.515, val acc 0.402<p>Epoch 12, train loss: 1.30, val loss: 1.56, train acc: 0.519, val acc 0.462<p>Epoch 13, train loss: 1.26, val loss: 1.43, train acc: 0.538, val acc 0.485<p>Epoch 14, train loss: 1.21, val loss: 1.47, train acc: 0.560, val acc 0.466<p>Epoch 15, train loss: 1.14, val loss: 1.15, train acc: 0.582, val acc 0.577<p>Epoch 16, train loss: 1.09, val loss: 1.13, train acc: 0.604, val acc 0.585<p>Epoch 17, train loss: 1.08, val loss: 1.13, train acc: 0.610, val acc 0.588<p>Epoch 18, train loss: 1.06, val loss: 1.13, train acc: 0.613, val acc 0.591<p>Epoch 19, train loss: 1.05, val loss: 1.13, train acc: 0.617, val acc 0.589<p>Epoch 20, train loss: 1.04, val loss: 1.11, train acc: 0.618, val acc 0.596<p>Epoch 21, train loss: 1.03, val loss: 1.12, train acc: 0.623, val acc 0.592<p>Epoch 22, train loss: 1.03, val loss: 1.11, train acc: 0.628, val acc 0.596<p>Epoch 23, train loss: 1.02, val loss: 1.12, train acc: 0.630, val acc 0.590<p>Epoch 24, train loss: 1.01, val loss: 1.09, train acc: 0.633, val acc 0.602<p>Epoch 25, train loss: 1.00, val loss: 1.09, train acc: 0.638, val acc 0.608<p>Epoch 26, train loss: 1.00, val loss: 1.09, train acc: 0.638, val acc 0.608<p>Epoch 27, train loss: 0.99, val loss: 1.08, train acc: 0.641, val acc 0.612<p>Epoch 28, train loss: 0.98, val loss: 1.08, train acc: 0.648, val acc 0.614<p>Epoch 29, train loss: 0.97, val loss: 1.08, train acc: 0.649, val acc 0.609
# Finished training after 383 seconds.

# %%
title = "Training Accuracy vs Epoch"
s.plot(
    title = title,
    label = "Accuracy",
    train_results = trainacc,
    val_results = valacc)

title = "Training Loss vs Epoch"
s.plot(
    title = title,
    label = "Loss",
    train_results = trainloss,
    val_results = valloss)

# %% [markdown]
# #### **Questions**
# - Does it improve performance?
# - What can you observe in the plots?

# %% [markdown]
# **Your answers here**
#
# 1. yes
# 2. i can observe where the lr chanegs the loss/acc changes slope

# %% [markdown]
# ## 7. LR-Scheduling _(Optional)_

# %% [markdown]
# #### TODO _(Optional)_
# - try two more scheduler: ExponentialLR and ReduceLROnPlateau
# - vary the parameters, which work best?
# - does it improve performance compared to no scheduler?
# - does it improve performance compared to StepLR?

# %%
# TODO (Optional): Train and plot with different schedulers

# %% [markdown]
# **Your answers here**
