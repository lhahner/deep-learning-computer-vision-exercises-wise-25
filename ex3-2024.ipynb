# %% [markdown]
# # Exercise Sheet 3 - Covid-19 Classification using Transfer Learning
#
# - Deep Learning for Computer Vision - Winter Term 2024/25
# - Lecture by: Constantin Pape
# - Tutors: Anwai Archit, Oleg Bakumenko, Luca Freckmann, Marei Freitag, Sarah Muth, Sushmita Nair
# - Due date: **Tuesday**, Dec 3, before 10:00
#
# ## Time Required to Solve this Exercise Sheet
#
# As you will train deep CNNs on this exercise sheet, model training will require an increased amount of time. So we recommend to start working on this sheet early.
#
# ## Topic
#
# In this exercise, you will solve an image classification task from medical imaging: classification in Chest X-Ray images into patients with Covid-19, Pneunomia or Healthy. We will use a subset of the dataset from a Kaggle challenge for this. (https://www.kaggle.com/datasets/prashant268/chest-xray-covid19-pneumonia)
#
# The main focus of this exercise is transfer learning and you will approach the classification task with three different approaches:
#
#     Training ResNets from scratch. (Note that we will use the ResNet implementation from torchvision throughout the exercise).
#     Training ResNets pretrained on ImageNet.
#     Training ResNets pretrained on RadImageNet, a large radiology dataset.
#
# In addition you can combine these approaches with other methods to improve the model at the end and upload your best solution on a hold-out test set. This is explained in more details at the end of the exercise.

# %% [markdown]
# ### Hints
#
# In the first part of the exercise you will train ResNets from scratch, analyze the effects of deeper models with small training data and use data augmentations. In the second part, you will solve the same task using pretrained ResNets (from ImageNet - pretrained on natural images; and RadImageNet - pretrained on the medical imaging domain).
#
# To understand the background of this exercise, you can:
# - Review the lectures
#     - Lecture 3 on CNNs
#     - Lecture 4 on Transfer Learning and Augmentaion
# - Check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315).
#
# At the end of the exercise you should further improve your model. You can draw upon a number of techniques we discussed for improving model performance. The predictions from your best model on a hold-out test set should be uploaded together with the exercise. More explanation is given at the end of the exercise sheet.
#
# _Do not hesitate to ask questions and ideally discuss them with the fellow students on Matrix! We will monitor the channel to provide you help if your discussions get stuck._

# %% [markdown]
# ## IMPORTANT SUBMISSION INSTRUCTIONS
# - **You need to answer all the questions in written form**
# - When you are done, download the notebook from Kaggle and **rename** it to `<surname1>_<surname2>_<surname3>.ipynb`
# - For the final submission:
#     - Submit the **Jupyter Notebook** (.ipynb file). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Notebook` -> `Tutorial <X>` (where, `X` is the tutorial you are assigned to).
#     - Submit the **Challenge Results** (.csv file) (for the unlabeled images, namely `unknown`). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results` -> `Tutorial <X>`
# - Make only one submission of the exercise and results per group.
# - The deadline is strict.
# - You have to present the exercise in the tutorials. We have a high ratio of students to tutors, so please decide which team member presents which part beforehand.
#
# Implementation
# - Do not change the cells which are marked as `DO NOT CHANGE`, similarly write your solution into the cells marked with TODOs and answer the **questions** asked. In addition to the python packages loaded below, you are allowed to use any packages you want.

# %% [markdown]
# **Importing required libraries:**
#
# We have provided the most essential libraries to be used for the exercise. Feel free to add modules as per your requirement.

# %%
import os
from glob import glob
from IPython.display import FileLink

import numpy as np
import imageio.v3 as imageio
import matplotlib.pyplot as plt

import torch
import torchvision
from torch import nn
import torch.optim as optim
import torchvision.transforms as transforms

# %pip install barbar
# Out:
# Collecting barbar
#   Downloading barbar-0.2.1-py3-none-any.whl.metadata (912 bytes)
# Downloading barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setting up the device (make sure device returns "cuda" to use of the GPUs on kaggle)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Getting the Required Functionalities
#
# We first download and import `ex3_utils.py`, which in which functions for training evaluation etc. are already implemented (similar to the previous exercise). You can download this file and inspect it on your computer to understand the functions it contains.
#
# You can either download it from google drive as here or from Stud.IP (it's provided there in the same folder as this notebook.)

# %%
# DO NOT CHANGE
# Download `ex3_utils.py` from Google Drive in Kaggle
# !conda install -y gdown

# File Location - https://drive.google.com/file/d/1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ/view?usp=sharing (we only need the id)
# !gdown 1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - rapidsai
#  - nvidia
#  - nodefaults
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-24.11.0              |  py310hff52083_0         907 KB  conda-forge
#     filelock-3.16.1            |     pyhd8ed1ab_0          17 KB  conda-forge
#     gdown-5.2.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.16.1-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-5.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   conda                              24.9.0-py310hff52083_0 --> 24.11.0-py310hff52083_0
#   openssl                                  3.3.2-hb9d3cd8_0 --> 3.4.0-hb9d3cd8_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.4.0        | 2.8 MB    |                                       |   0%
# conda-24.11.0        | 907 KB    |                                       |   0%
#
# gdown-5.2.0          | 21 KB     |                                       |   0%
#
#
# filelock-3.16.1      | 17 KB     |                                       |   0%
#
#
# filelock-3.16.1      | 17 KB     | ##################################### | 100%
#
# gdown-5.2.0          | 21 KB     | ##################################### | 100%
# openssl-3.4.0        | 2.8 MB    | ##################################### | 100%
# conda-24.11.0        | 907 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Downloading...
# From (original): https://drive.google.com/uc?id=1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ
# From (redirected): https://drive.google.com/uc?id=1VfnvYTwNbDdwFArYZqZuqhkmw9d39IgQ&confirm=t&uuid=f355e1f1-716c-4889-93ff-cd09c7aad373
# To: /kaggle/working/ex3_utils.py
# 100%|██████████████████████████████████████| 10.4k/10.4k [00:00<00:00, 35.3MB/s]

# %%
# DO NOT CHANGE
# Import `ex3_utils.py`
import ex3_utils as utils

# %% [markdown]
# ### Data Preparation
#
# We download the data from google drive and unzip the data in `"/kaggle/working/covid19"`.
#
# NOTE: If you are working on another system besides Kaggle, you should update the base directory (`/kaggle/working`) to your desired filepath.

# %%
# DO NOT CHANGE
# Downloading the "Chest X-ray (Covid-19 & Pneumonia)" data from owncloud
# !wget https://owncloud.gwdg.de/index.php/s/dcvhmxtksDDDtK8/download -O covid19-xray.zip

# Unzipping the dataset
# !unzip -q "/kaggle/working/covid19-xray.zip"
# Out:
# --2024-12-01 09:50:19--  https://owncloud.gwdg.de/index.php/s/dcvhmxtksDDDtK8/download
# Resolving owncloud.gwdg.de (owncloud.gwdg.de)... 134.76.23.45
# Connecting to owncloud.gwdg.de (owncloud.gwdg.de)|134.76.23.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154704441 (148M) [application/zip]
# Saving to: 'covid19-xray.zip'
#
# covid19-xray.zip    100%[===================>] 147.54M  18.1MB/s    in 9.2s
#
# 2024-12-01 09:50:29 (16.0 MB/s) - 'covid19-xray.zip' saved [154704441/154704441]

# %%
# DO NOT CHANGE
# Setting the path to covid-19 dataset
root_dir = "/kaggle/working/"
data_folder = os.path.join(root_dir, "covid19")

# %% [markdown]
# **Data exploration**
#
# The data is stored in the root folder `covid19` (in `"/kaggle/working"`) and contains four subfolders, namely `train`, `val`, `test` and `unknown` with training / validation / testing split and the hold-out test set, respectively. Each of these (except `unknown`) contains subfolders with the images for the respective classes. As a first step, we will visualize some of the images and labels from the training data.
#
# We will not use the `unknown` directory for training or evaluation, but will only use it for prediction with the best model at the end.

# %%
# DO NOT CHANGE
# Checking the number of classes
train_class_dirs = glob(os.path.join(data_folder, "train", "*"))
val_class_dirs = glob(os.path.join(data_folder, "val", "*"))
test_class_dirs = glob(os.path.join(data_folder, "test", "*"))
assert len(train_class_dirs) == len(val_class_dirs) == len(test_class_dirs) == 3

# %%
# DO NOT CHANGE
# Checking the expected structure of all images
image_paths = glob(os.path.join(data_folder, "**", "*.jpg"), recursive=True)
assert len(image_paths) == (450 + 150 + 225 + 5607), len(image_paths)  # 450 train samples, 150 val samples, 225 test samples, 5607 unlabeled samples (hold-out test)

# %% [markdown]
# Let's plot samples from each class in the training set:

# %%
# Classes available for the task
classes = ["COVID19", "NORMAL", "PNEUMONIA"]
num_classes = 3

# TODO: YOUR SOLUTION HERE
import random

image_paths = []

for folder in train_class_dirs:
    images = os.listdir(folder)
    random_images = random.sample(images, 3)
    image_paths.extend([os.path.join(folder, img) for img in random_images])

fig, axes = plt.subplots(3, 3, figsize=(10, 10))

for i, ax in enumerate(axes.flat):
    img = imageio.imread(image_paths[i])
    ax.imshow(img)
    ax.axis('off')

for i, ax in enumerate(axes[0]):
    ax.set_title(os.path.basename(train_class_dirs[0]), fontsize=14)
for i, ax in enumerate(axes[1]):
    ax.set_title(os.path.basename(train_class_dirs[1]), fontsize=14)
for i, ax in enumerate(axes[2]):
    ax.set_title(os.path.basename(train_class_dirs[2]), fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# You should see x-ray images from each class and their corresponding labels in their titles. To reflect on our understanding of the dataset, please answer the following **questions**:
# - How many classes are provided in the datasets?
# - Are the images balanced along all the classes in the respective data splits?

# %% [markdown]
# Let's set the directories for the respective datasets

# %%
# Splits for the dataset 
train_dir = os.path.join(data_folder, "train")
val_dir = os.path.join(data_folder, "val")
test_dir = os.path.join(data_folder, "test")
unknown_dir = os.path.join(data_folder, "unknown")

# %% [markdown]
# Now, we obtain the statistics (mean and standard deviation) from the training dataset to be used for normalizing the datasets

# %%
# DO NOT CHANGE
train_images = []
for class_name in classes:
    train_images.extend(glob(os.path.join(train_dir, class_name, "*.jpg")))

to_tensor = torchvision.transforms.ToTensor()
imgs = torch.stack([to_tensor(imageio.imread(im)) for im in train_images])
print(imgs.shape)

# And then compute the mean and standard deviation independently for the image channels.
# (The channels are stored in dim=1, by excluding this below we achieve this.)
mean = torch.mean(imgs, dim=(0, 2, 3))
std = torch.std(imgs, dim=(0, 2, 3))

# Delete the images again in order to save memory.
del imgs

print(mean)
print(std)
# Out:
# torch.Size([450, 3, 512, 512])
# tensor([0.4949, 0.4952, 0.4957])
# tensor([0.2298, 0.2298, 0.2298])

# %%
train_dataset_mean = mean
train_dataset_std = std

# %% [markdown]
# **Implement PyTorch dataloader**
#
# As a next step, we implement a `torch.utils.data.Dataset` followed by the `torch.utils.data.DataLoader` to have access to our data during training, validation and testing. In our case, the data is stored in a format that is already compatible with `torchvision.datasets.ImageFolder`.

# %% [markdown]
# To use the image data in PyTorch it first needs to be transformed. You can use the transformations from [torchvision.transforms](https://pytorch.org/vision/0.9/transforms.html) for this. Here, we need to:
# - Convert the image data to a `torch.tensor` (`transforms.ToTensor`)
# - Standardize the inputs based on their data statistics (`transforms.Normalize`)
# - Resize the images (`transforms.Resize`). Note that resizing is not strictly necessary, but will speed up training and resize the images to a size that better matches the ImageNet pretraining data.
#
# To combine several transforms together, you can use `torchvision.transforms.Compose` by passing the list of 'transform' objects to compose.

# %%
# We resize the images to the size 256 x 256 to speed up training
height = width = 256

# Get the usual transforms to have the inputs from dataloaders as expected
def get_transforms(height, width):
    # TODO: YOUR CODE HERE
    transform = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize(train_dataset_mean,train_dataset_std), 
        transforms.Resize(height)
    ])
    return transform

trans = get_transforms(height,width)

# %%
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE

from torchvision import datasets
from torch.utils.data import DataLoader

train_dataset = datasets.ImageFolder(train_dir, transform=trans)
val_dataset = datasets.ImageFolder(val_dir, transform=trans)
test_dataset = datasets.ImageFolder(test_dir, transform=trans)

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Now let's visualize the images after transformation as they are returned from the training loader.

# %%
# Function to show images
fig = plt.figure(figsize=(10, 15))
def imshow(img):
    img = img / 2 + 0.5  # unnormalise
    npimg = img.numpy()
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# Obtain random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Show the images
imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s, ' % classes[labels[j]] for j in range(len(labels))))
# Out:
# COVID19,  PNEUMONIA,  NORMAL,  PNEUMONIA,  PNEUMONIA,  COVID19,  NORMAL,  NORMAL,  NORMAL,  NORMAL,  NORMAL,  NORMAL,  PNEUMONIA,  NORMAL,  COVID19,  NORMAL,

# %%
results = dict()

# %% [markdown]
# ## Architecture
#
# We will use the ResNet implementation from torchvision, see https://pytorch.org/vision/stable/models.html, for this exercise.
#
# - We start with the smallest ResNet model, the ResNet18 (https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - And will then use deeper ResNets to explore how well larger models can be trained on a small dataset.
# - To use random weight initialization (in order to train from scratch), you can just create models without passing additional arguments like so: `torchvision.models.<MODEL_NAME>()`.

# %% [markdown]
# We need to adapt the model to fit with our purpose. For this, we must change the output dimension of the last fully-connected layer to consider the number of classes in our problem. Let's check the last layer out.

# %%
# Let's get the resnet18 architecture and understanding the backbone (in order to adapt it to our problem)
# TODO: YOUR SOLUTION HERE

model = torchvision.models.resnet18()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# We see above that there is a component called `fc` that consists of a `Linear` layer. To make use of ResNet18 for our classification task, we need to change the `out_features` of the linear layer to the number of classes of our problem. In our case, it's `num_classes` (=3).

# %%
print(model.fc)
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %% [markdown]
# To replace the last layer (classification layer) you can use the following code. (Here we provide a stand-alone code snippet)
#
# ```python
# import torchvision
# import torch.nn as nn
#
# model = torchvision.models.resnet18()
#
# # Let's replace the "fully connected" layer to match our expected output classes
# model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
# model.to(device)
# ```

# %%
# Replacing the last layer(s) of ResNet18 to match our number of classes
# TODO: YOUR SOLUTION HERE
model = torchvision.models.resnet18()
model.fc = nn.Linear(512, 3)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet18'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-resnet18-from-scratch.pt

# %% [markdown]
# If you now display the model (using `print(model)`) you should see that its last layer has been updated.

# %% [markdown]
# ### Training
#
# Let's train the model for 10 epochs, using the `Adam` optimizer, `CrossEntropyLoss` as the criterion (loss function) and a learning rate scheduler (e.g. `ReduceLROnPlateau`).

# %%
# Clearing the GPU cache
torch.cuda.empty_cache()


print("Starting training from scratch with network: ", model_name)

lr=0.0001
patience=10
num_epochs = 10

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)


# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# Starting training from scratch with network:  resnet18
# 450/450: [==============================>.] - ETA 1.1ss
# Epoch: 1
# Training Loss: 0.568 , Training Accuracy:0.796 => Validation Loss: 1.681, Validation Accuracy: 0.507
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 2
# Training Loss: 0.578 , Training Accuracy:0.778 => Validation Loss: 0.589, Validation Accuracy: 0.833
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 3
# Training Loss: 0.326 , Training Accuracy:0.887 => Validation Loss: 0.458, Validation Accuracy: 0.840
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 4
# Training Loss: 0.238 , Training Accuracy:0.916 => Validation Loss: 0.451, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 5
# Training Loss: 0.306 , Training Accuracy:0.889 => Validation Loss: 0.873, Validation Accuracy: 0.687
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 6
# Training Loss: 0.308 , Training Accuracy:0.882 => Validation Loss: 0.410, Validation Accuracy: 0.860
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 7
# Training Loss: 0.175 , Training Accuracy:0.927 => Validation Loss: 0.508, Validation Accuracy: 0.873
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 8
# Training Loss: 0.193 , Training Accuracy:0.933 => Validation Loss: 0.548, Validation Accuracy: 0.787
# EarlyStopping Counter: 2 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 9
# Training Loss: 0.328 , Training Accuracy:0.858 => Validation Loss: 0.457, Validation Accuracy: 0.833
# EarlyStopping Counter: 3 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 10
# Training Loss: 0.299 , Training Accuracy:0.876 => Validation Loss: 0.370, Validation Accuracy: 0.887
# Finished Training

# %% [markdown]
# Now, let's see how the accuracy and loss plots look for our training.

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(accuracy, val_accuracy, "accuracy")


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(losses,val_losses, "loss")

# %% [markdown]
# ### Evaluation on the test set
#
# Let's check the test accuracy and confusion matrix. All the required functionality is already provided in `ex3_utils.py` and you just need to read the corresponding functions to understand how to call them here.

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))

results[model_name] = 100 * correct / total
# Out:
# Accuracy of /kaggle/working/covid-19-resnet18-from-scratch.pt on the Test Images: 89 %

# %%
# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
cm = utils.get_confusion_matrix(classes, test_loader,model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)
# Out:
# COVID19 - recall :  0.9375  precision :  1.0  accuracy :  0.9777778
# NORMAL - recall :  0.8313253  precision :  0.92  accuracy :  0.9111111
# PNEUMONIA - recall :  0.9354839  precision :  0.7733333  accuracy :  0.9066667

# %%
# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# 0.8977777777777778

# %% [markdown]
# Now let's try training deeper ResNet architectures using the same hyperparameters from above:
# - Train and evaluate a ResNet34 from scratch.
# - Train and evaluate a ResNet50 from scratch.

# %%
# TODO: YOUR SOLUTIONS HERE
torch.cuda.empty_cache()

# ResNet34
model = torchvision.models.resnet34()
model.fc = nn.Linear(512, 3)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet34'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)


# HINT: (for the workflow)
#    - Start with training a ResNet34:
#          - Updating the last layers (training the network from scratch)
#          - REMEMBER: Save the respective checkpoints uniquely, and initialize the early stopping with them.
#          - Use the expected hyperparameters for training
#          - Observe the loss and accuracy curves for training and validation
#    - Next, train a ResNet50 (following the same suggestion as above)
#    - Finally, evaluate both the trained models from above on the test set and answer the questions.
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-resnet34-from-scratch.pt
# Starting training from scratch with network:  resnet34
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 1
# Training Loss: 0.628 , Training Accuracy:0.747 => Validation Loss: 2.227, Validation Accuracy: 0.500
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 2
# Training Loss: 0.990 , Training Accuracy:0.602 => Validation Loss: 0.976, Validation Accuracy: 0.620
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 3
# Training Loss: 0.603 , Training Accuracy:0.720 => Validation Loss: 0.964, Validation Accuracy: 0.653
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 4
# Training Loss: 0.479 , Training Accuracy:0.773 => Validation Loss: 0.555, Validation Accuracy: 0.847
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 5
# Training Loss: 0.345 , Training Accuracy:0.884 => Validation Loss: 0.456, Validation Accuracy: 0.827
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 6
# Training Loss: 0.265 , Training Accuracy:0.902 => Validation Loss: 0.393, Validation Accuracy: 0.840
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 7
# Training Loss: 0.196 , Training Accuracy:0.924 => Validation Loss: 0.454, Validation Accuracy: 0.787
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 8
# Training Loss: 0.274 , Training Accuracy:0.904 => Validation Loss: 0.404, Validation Accuracy: 0.847
# EarlyStopping Counter: 2 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 9
# Training Loss: 0.383 , Training Accuracy:0.876 => Validation Loss: 1.194, Validation Accuracy: 0.620
# EarlyStopping Counter: 3 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 10
# Training Loss: 0.556 , Training Accuracy:0.789 => Validation Loss: 0.381, Validation Accuracy: 0.880
# Finished Training
# Accuracy of /kaggle/working/covid-19-resnet34-from-scratch.pt on the Test Images: 88 %
# COVID19 - recall :  0.9480519  precision :  0.97333336  accuracy :  0.97333336
# NORMAL - recall :  0.8023256  precision :  0.92  accuracy :  0.8977778
# PNEUMONIA - recall :  0.91935486  precision :  0.76  accuracy :  0.8977778
# 0.8844444444444445

# %%
torch.cuda.empty_cache()

# ResNet50
model = torchvision.models.resnet50()
model.fc = nn.Linear(2048, 3)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet50'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-resnet50-from-scratch.pt
# Starting training from scratch with network:  resnet50
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 1
# Training Loss: 0.813 , Training Accuracy:0.636 => Validation Loss: 2.904, Validation Accuracy: 0.333
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 2
# Training Loss: 1.233 , Training Accuracy:0.453 => Validation Loss: 0.791, Validation Accuracy: 0.660
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.668 , Training Accuracy:0.687 => Validation Loss: 0.673, Validation Accuracy: 0.660
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.572 , Training Accuracy:0.738 => Validation Loss: 1.162, Validation Accuracy: 0.600
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.613 , Training Accuracy:0.751 => Validation Loss: 0.588, Validation Accuracy: 0.793
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.434 , Training Accuracy:0.820 => Validation Loss: 0.641, Validation Accuracy: 0.733
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.431 , Training Accuracy:0.842 => Validation Loss: 0.501, Validation Accuracy: 0.840
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.415 , Training Accuracy:0.849 => Validation Loss: 0.640, Validation Accuracy: 0.700
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.281 , Training Accuracy:0.896 => Validation Loss: 0.433, Validation Accuracy: 0.873
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.220 , Training Accuracy:0.904 => Validation Loss: 0.437, Validation Accuracy: 0.847
# EarlyStopping Counter: 1 out of 10
# Finished Training
# Accuracy of /kaggle/working/covid-19-resnet50-from-scratch.pt on the Test Images: 86 %
# COVID19 - recall :  0.95714283  precision :  0.8933333  accuracy :  0.95111114
# NORMAL - recall :  0.7802198  precision :  0.94666666  accuracy :  0.8933333
# PNEUMONIA - recall :  0.875  precision :  0.74666667  accuracy :  0.88
# 0.8622222222222222

# %% [markdown]
# **Questions**:
#
# 1. How does the performance of the three architectures compare to each other? Are there any specific patterns you can see in the confusion matrices?
# 2. Is there a correlation between the dataset size and depth of the network?
# 3. Given these observations, which model would you prefer for training on a small dataset from scratch?

# %%
for res in results:
    print(f"{res} accuracy: {round(results[res])}%" )
# Out:
# resnet18 accuracy: 90%
# resnet34 accuracy: 88%
# resnet50 accuracy: 86%

# %% [markdown]
# **ANSWER:**
#
#
#
# 1. The performance is the best for the ResNet18. It returned the highest test accuracy and also the plots looked the best. The accuracy plot shows some fluctuation but not that much and is overall increasing. The loss plot shows low values for the loss and represents an expected curve. The confusion matrix has high values in the diagonal from upper left to lower right corner and lower values in the other corners. The same structure holds for the other models but for the ResNet18 the values are more extreme. The ResNet34 is the second best and the ResNet50 performs the worst which can be seen in the plots, the test accuracy, and the confusion matrix with the same reasons as mentioned before.
#
#
# 3. The dataset is pretty small with only 450 images. The models perform worse the larger they get. So probably yes, there could be a correlation between the size of the dataset and the depth of the network. Deep networks tend more easily to overfit when trained on small datasets. This aligns with the plot for the losses of the ResNet50 which shows small signs of overfitting.
#
#
#
# 4. Probably the ResNet18 is the best because it returns the highest test accuracy and the plots look like they are wished to. If the dataset is a little bit bigger also the ResNet34 still works good and could be an even better choice.

# %% [markdown]
# #### Now let's try with **Data Augmentation**
#
# A common strategy when dealing with small datasets is to add data augmentations.
#
# Let's try a few augmentations from [torchvision.transforms](https://pytorch.org/vision/main/transforms.html) that do not significantly distort the data (stay on the data manifold) and train a ResNet50. Here, we want to see if augmentations allow us to train deeper CNNs.
# Common augmentations for data augmentation are:
# - flipping the inputs along the axes.
# - changing the brightness, contrast and saturation of the inputs.
# - adding small noise to the input.
#
# You can try different combinations of augmentations here. You can add augmentations by updating the `transform` passed to the train dataset. You can again use `Compose` to chain augmentations.
#
# Note; you should only introduce augmentation for the training and validation datasets, **not** for the test dataset. Otherwise the evaluation between models is not consistent anymore.

# %%
# TODO: YOUR SOLUTIONS HERE

def get_transforms_augmentation(height, width):

    # TODO: YOUR CODE HERE

    transform = transforms.Compose([
        # Data Augmentations
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(10),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 
        transforms.Resize((height, width)),
        transforms.ToTensor(),
        transforms.Normalize(train_dataset_mean,train_dataset_std)

    ])

    return transform

# HINT:
#    - Training a ResNet50 (incorporating data augmentation strategies)
#    = (the training workflows are the same as above)

# %% [markdown]
# We need to apply the new transforms to the dataset and then use our dataloader. Let's reuse our scripts from above, now with the added data augmentation strategies.

# %%
from torch.utils.data import ConcatDataset

transform_data_augmentation = get_transforms_augmentation(256,256)

# Datasets
train_dataset_augmented = datasets.ImageFolder(train_dir, transform=transform_data_augmentation)
val_dataset_augmented = datasets.ImageFolder(val_dir, transform=transform_data_augmentation)

# Combine the datasets using ConcatDataset
full_train_dataset = ConcatDataset([train_dataset, train_dataset_augmented])
full_val_dataset = ConcatDataset([val_dataset, val_dataset_augmented])

# Dataloaders
train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(full_val_dataset, batch_size=batch_size, shuffle=False)

# %%
# Function to show images
fig = plt.figure(figsize=(10, 15))
def imshow(img):
    img = img / 2 + 0.5  # unnormalise
    npimg = img.numpy()
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# Obtain random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Show the images
imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s, ' % classes[labels[j]] for j in range(len(labels))))
# Out:
# NORMAL,  PNEUMONIA,  COVID19,  COVID19,  PNEUMONIA,  PNEUMONIA,  NORMAL,  NORMAL,  COVID19,  COVID19,  PNEUMONIA,  NORMAL,  NORMAL,  PNEUMONIA,  NORMAL,  PNEUMONIA,

# %% [markdown]
# Now, we are ready to train the ResNet50 with data augmentations. Let's train for longer (30 epochs) here, with the same hyperparameters as before, and evaluate the model on the test set.

# %%
# TODO: YOUR SOLUTION HERE
torch.cuda.empty_cache()

# ResNet50
model = torchvision.models.resnet50()
model.fc = nn.Linear(2048, 3)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet50_data_augmented'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

num_epochs = 30

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  /kaggle/working/covid-19-resnet50_data_augmented-from-scratch.pt
# Starting training from scratch with network:  resnet50_data_augmented
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 1
# Training Loss: 0.898 , Training Accuracy:0.580 => Validation Loss: 1.053, Validation Accuracy: 0.553
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 2
# Training Loss: 0.991 , Training Accuracy:0.582 => Validation Loss: 0.866, Validation Accuracy: 0.587
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 3
# Training Loss: 0.686 , Training Accuracy:0.730 => Validation Loss: 0.619, Validation Accuracy: 0.753
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 4
# Training Loss: 0.566 , Training Accuracy:0.777 => Validation Loss: 0.791, Validation Accuracy: 0.687
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 5
# Training Loss: 0.511 , Training Accuracy:0.790 => Validation Loss: 0.860, Validation Accuracy: 0.697
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 6
# Training Loss: 0.443 , Training Accuracy:0.836 => Validation Loss: 0.458, Validation Accuracy: 0.833
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 7
# Training Loss: 0.414 , Training Accuracy:0.847 => Validation Loss: 0.485, Validation Accuracy: 0.830
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 8
# Training Loss: 0.338 , Training Accuracy:0.873 => Validation Loss: 0.543, Validation Accuracy: 0.757
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 9
# Training Loss: 0.314 , Training Accuracy:0.876 => Validation Loss: 0.445, Validation Accuracy: 0.837
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 10
# Training Loss: 0.237 , Training Accuracy:0.906 => Validation Loss: 0.325, Validation Accuracy: 0.873
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 11
# Training Loss: 0.248 , Training Accuracy:0.914 => Validation Loss: 0.393, Validation Accuracy: 0.880
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 12
# Training Loss: 0.208 , Training Accuracy:0.930 => Validation Loss: 0.316, Validation Accuracy: 0.883
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 13
# Training Loss: 0.236 , Training Accuracy:0.918 => Validation Loss: 0.422, Validation Accuracy: 0.860
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 14
# Training Loss: 0.279 , Training Accuracy:0.889 => Validation Loss: 0.378, Validation Accuracy: 0.883
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 15
# Training Loss: 0.223 , Training Accuracy:0.918 => Validation Loss: 0.318, Validation Accuracy: 0.910
# EarlyStopping Counter: 3 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 16
# Training Loss: 0.225 , Training Accuracy:0.907 => Validation Loss: 0.362, Validation Accuracy: 0.877
# EarlyStopping Counter: 4 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 17
# Training Loss: 0.258 , Training Accuracy:0.898 => Validation Loss: 0.368, Validation Accuracy: 0.853
# EarlyStopping Counter: 5 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 18
# Training Loss: 0.158 , Training Accuracy:0.947 => Validation Loss: 0.305, Validation Accuracy: 0.887
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 19
# Training Loss: 0.136 , Training Accuracy:0.950 => Validation Loss: 0.377, Validation Accuracy: 0.890
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 20
# Training Loss: 0.161 , Training Accuracy:0.941 => Validation Loss: 0.379, Validation Accuracy: 0.887
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 21
# Training Loss: 0.139 , Training Accuracy:0.947 => Validation Loss: 0.391, Validation Accuracy: 0.887
# EarlyStopping Counter: 3 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 22
# Training Loss: 0.143 , Training Accuracy:0.952 => Validation Loss: 0.344, Validation Accuracy: 0.897
# EarlyStopping Counter: 4 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 23
# Training Loss: 0.155 , Training Accuracy:0.947 => Validation Loss: 0.337, Validation Accuracy: 0.883
# EarlyStopping Counter: 5 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 24
# Training Loss: 0.140 , Training Accuracy:0.946 => Validation Loss: 0.329, Validation Accuracy: 0.910
# EarlyStopping Counter: 6 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 25
# Training Loss: 0.183 , Training Accuracy:0.934 => Validation Loss: 0.480, Validation Accuracy: 0.877
# EarlyStopping Counter: 7 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 26
# Training Loss: 0.204 , Training Accuracy:0.934 => Validation Loss: 0.302, Validation Accuracy: 0.900
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 27
# Training Loss: 0.088 , Training Accuracy:0.972 => Validation Loss: 0.467, Validation Accuracy: 0.870
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 28
# Training Loss: 0.123 , Training Accuracy:0.954 => Validation Loss: 0.364, Validation Accuracy: 0.873
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 29
# Training Loss: 0.087 , Training Accuracy:0.968 => Validation Loss: 0.411, Validation Accuracy: 0.883
# EarlyStopping Counter: 3 out of 10
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 30
# Training Loss: 0.130 , Training Accuracy:0.953 => Validation Loss: 0.284, Validation Accuracy: 0.910
# Finished Training
# Accuracy of /kaggle/working/covid-19-resnet50_data_augmented-from-scratch.pt on the Test Images: 89 %
# COVID19 - recall :  0.9736842  precision :  0.9866667  accuracy :  0.9866667
# NORMAL - recall :  0.84415585  precision :  0.8666667  accuracy :  0.9022222
# PNEUMONIA - recall :  0.8611111  precision :  0.82666665  accuracy :  0.8977778
# 0.8933333333333333

# %%
for res in results:
    print(f"{res} accuracy: {round(results[res])}%" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for res in results:
#       2     print(f"{res} accuracy: {round(results[res])}%" )
#
# NameError: name 'results' is not defined

# %% [markdown]
# **Questions**:
#
# 1. Does the effect of data augmentation match your expectation?
# 2. Are there other kinds of data augmentation that would make sense for this dataset? Think about augmentations that "leave the data manifold".

# %% [markdown]
# **Answers**
#
# 1. Yes, the model returns slightly better results. The test accuracy is a little higher and less signs for overfitting occur in the plots. Also the values of the confusion matrix look a little better. The changes are low so far but the performance increased a little bit because the size of the dataset increased with the data augmentation.
#
# 2. Other kinds of transformations that fit the dataset and leave the data in the manifold could be the ones that we used, like slightly rotating or translating vertically or horizontally the images (to simulate different postures of the patients).

# %% [markdown]
# ## ImageNet
#
# The [ImageNet project](https://www.image-net.org/) provides a large-scale dataset with natural images. There exist different version of this dataset, the largest using 14 million annotated images for image classification with over 20,000 categories.
#
# This dataset has been used by the ImageNet Scale Visual Recognition Challenge ([ILSVRC](https://image-net.org/challenges/LSVRC/#:~:text=The%20ImageNet%20Large%20Scale%20Visual,image%20classification%20at%20large%20scale.)) to benchmark classification algorithms competing to improve classification. The version fo the dataset used for this classification contains a million training images with 1,000 categeories (and corresponds to the version fo the dataset we discussed in the lecture).
#
# `torchvision.models` has a pool of neural networks, for which pretrained ImageNet weights are also available. To make use of pretrained models, we need to preprocess the images based on the mean and standard deviation of ImageNet (this step is critical!). The statistics for ImageNet are provided [here](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet50.html#:~:text=1.0%5D%20and%20then-,normalized%20using%20mean%3D%5B0.485%2C%200.456%2C%200.406%5D%20and%20std%3D%5B0.229%2C%200.224%2C%200.225%5D.,-Next).
#
# ### ImageNet transfer learning for ResNet50
#
# We will now check if transfer learning from ImageNet leads to improvements for our dataset. Here, we will focus on the ResNet50 as we have seen before that without transfer learning its performance is worse compared to smaller architectures for our dataset.
#
# There are two different approaches for how we can fine-tune a CNN initialized with pretrained weights:
# 1. Update the weights for all layers of the network. For this approach we initialize with pretrained weights but otherwise train the network as before. See this code snippet:
#
#     ```python
#     import torchvision
#     import torch.nn as nn
#
#     model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
#
#     # Let's replace the "fully connected" layer to match our expected output classes
#     model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
#     model.to(device)
#
#     # Train the network as usual
#     ```
#
# 2. Only update the weights of the last layer (classification layer). In this case we would "freeze" the pretrained network and use it as a fixed feature extractor. This is achieved by disabling parameter updates for all but the last layer of the network.
#
# We will start with the first approach (fine-tuning the full network).

# %%
trans = get_transforms(height,width)
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE

from torchvision import datasets
from torch.utils.data import DataLoader

train_dataset = datasets.ImageFolder(train_dir, transform=trans)
val_dataset = datasets.ImageFolder(val_dir, transform=trans)
test_dataset = datasets.ImageFolder(test_dir, transform=trans)

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TODO: YOUR SOLUTIONS HERE
# Finetuning Full Network

model_imagenet_1 = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)



# Let's replace the "fully connected" layer to match our expected output classes

model_imagenet_1.fc = nn.Linear(2048, 3)

model_imagenet_1.to(device)



model_name = 'restnet50-transfer-learning-1'

checkpoint_name = f'covid-19-model{model_name}.pt'

checkpoint_path = os.path.join(root_dir, checkpoint_name)


num_epochs = 100



criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_imagenet_1.parameters(), lr=lr)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path, patience=patience)


accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model_imagenet_1, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)




utils.get_metric_plots(accuracy, val_accuracy, "accuracy")
utils.get_metric_plots(losses,val_losses, "loss")


model_imagenet_1.load_state_dict(torch.load(checkpoint_path, weights_only=True))



correct, total = utils.test_evaluation(model_imagenet_1, test_loader, device)

print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total


cm = utils.get_confusion_matrix(classes, test_loader, model_imagenet_1, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)
# Out:
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 1
# Training Loss: 0.680 , Training Accuracy:0.829 => Validation Loss: 0.518, Validation Accuracy: 0.873
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 2
# Training Loss: 0.339 , Training Accuracy:0.871 => Validation Loss: 0.401, Validation Accuracy: 0.887
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.151 , Training Accuracy:0.951 => Validation Loss: 0.232, Validation Accuracy: 0.907
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.121 , Training Accuracy:0.949 => Validation Loss: 0.181, Validation Accuracy: 0.933
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.120 , Training Accuracy:0.947 => Validation Loss: 0.121, Validation Accuracy: 0.953
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.102 , Training Accuracy:0.958 => Validation Loss: 0.460, Validation Accuracy: 0.860
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.110 , Training Accuracy:0.967 => Validation Loss: 0.207, Validation Accuracy: 0.920
# EarlyStopping Counter: 2 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.052 , Training Accuracy:0.982 => Validation Loss: 0.167, Validation Accuracy: 0.947
# EarlyStopping Counter: 3 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.025 , Training Accuracy:0.991 => Validation Loss: 0.149, Validation Accuracy: 0.927
# EarlyStopping Counter: 4 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.004 , Training Accuracy:1.000 => Validation Loss: 0.148, Validation Accuracy: 0.953
# EarlyStopping Counter: 5 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 11
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.152, Validation Accuracy: 0.960
# EarlyStopping Counter: 6 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 12
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.156, Validation Accuracy: 0.960
# EarlyStopping Counter: 7 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 13
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.157, Validation Accuracy: 0.960
# EarlyStopping Counter: 8 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 14
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.159, Validation Accuracy: 0.960
# EarlyStopping Counter: 9 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 15
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.161, Validation Accuracy: 0.960
# EarlyStopping Counter: 10 out of 10
# Early Stopping...
# Finished Training
# Accuracy of /kaggle/working/covid-19-modelrestnet50-transfer-learning-1.pt on the Test Images: 92 %
# COVID19 - recall :  1.0  precision :  1.0  accuracy :  1.0
# NORMAL - recall :  0.8518519  precision :  0.92  accuracy :  0.92
# PNEUMONIA - recall :  0.9130435  precision :  0.84  accuracy :  0.92
# 0.92

# %% [markdown]
# Now let's try the second approach and finetune only the last layer.
#
# By default all parameters of a network will be updated by gradient descent. The gradient updates can be disabled by setting `requires_grad = False`. So in order to finetune only the last layer you need to `requires_grad = False` for all other layers in the network.
#
# You can see how the parameters are disabled for a complete model in the code snippet below. For the next exercise you need to make sure that `requires_grad` stays `True` for the last layer!
#
# ```python
# for param_name, param in model.named_parameters():
#     param.requires_grad = False
# ```

# %%
from re import U

# TODO: YOUR SOLUTIONS HERE



model_imagenet_2 = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)



num_features = model_imagenet_2.fc.in_features

model_imagenet_2.fc = nn.Linear(num_features, 3)

model_imagenet_2.to(device)



# Freeze all parameters except the last layer

for param_name, param in model_imagenet_2.named_parameters():

    param.requires_grad = False



# Ensure the last layer (fc) is trainable

for param_name, param in model_imagenet_2.fc.named_parameters():

    param.requires_grad = True



# Check that only the last layer is trainable

trainable_params = [name for name, param in model_imagenet_2.named_parameters() if param.requires_grad]

print("Trainable parameters:", trainable_params)



model_name = 'restnet50-transfer-learning-2'

checkpoint_name = f'covid-19-model{model_name}.pt'

checkpoint_path = os.path.join(root_dir, checkpoint_name)



criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(model_imagenet_2.parameters(), lr=lr)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path, patience=patience)



num_epochs = 30
accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model_imagenet_2, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)



utils.get_metric_plots(accuracy, val_accuracy, "accuracy")
utils.get_metric_plots(losses,val_losses, "loss")




model_imagenet_2.load_state_dict(torch.load(checkpoint_path, weights_only=True))



correct, total = utils.test_evaluation(model_imagenet_2, test_loader, device)

print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total



cm = utils.get_confusion_matrix(classes, test_loader, model_imagenet_2, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)





# HINT:

#    - Training a ResNet50 (updating the last layers, transfer learning using ImageNet weights)

#    = (the training workflows are the same as above)
# Out:
# Trainable parameters: ['fc.weight', 'fc.bias']
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 1
# Training Loss: 1.091 , Training Accuracy:0.376 => Validation Loss: 1.101, Validation Accuracy: 0.353
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 2
# Training Loss: 1.077 , Training Accuracy:0.420 => Validation Loss: 1.055, Validation Accuracy: 0.513
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 3
# Training Loss: 1.026 , Training Accuracy:0.547 => Validation Loss: 1.013, Validation Accuracy: 0.620
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 4
# Training Loss: 0.979 , Training Accuracy:0.698 => Validation Loss: 0.974, Validation Accuracy: 0.687
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 5
# Training Loss: 0.945 , Training Accuracy:0.756 => Validation Loss: 0.930, Validation Accuracy: 0.827
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 6
# Training Loss: 0.905 , Training Accuracy:0.840 => Validation Loss: 0.906, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 7
# Training Loss: 0.873 , Training Accuracy:0.876 => Validation Loss: 0.874, Validation Accuracy: 0.860
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 8
# Training Loss: 0.838 , Training Accuracy:0.876 => Validation Loss: 0.846, Validation Accuracy: 0.873
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 9
# Training Loss: 0.817 , Training Accuracy:0.851 => Validation Loss: 0.819, Validation Accuracy: 0.860
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 10
# Training Loss: 0.778 , Training Accuracy:0.873 => Validation Loss: 0.787, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 11
# Training Loss: 0.756 , Training Accuracy:0.889 => Validation Loss: 0.781, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 12
# Training Loss: 0.727 , Training Accuracy:0.891 => Validation Loss: 0.756, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 13
# Training Loss: 0.713 , Training Accuracy:0.882 => Validation Loss: 0.731, Validation Accuracy: 0.893
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 14
# Training Loss: 0.681 , Training Accuracy:0.889 => Validation Loss: 0.715, Validation Accuracy: 0.860
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 15
# Training Loss: 0.669 , Training Accuracy:0.887 => Validation Loss: 0.693, Validation Accuracy: 0.887
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 16
# Training Loss: 0.650 , Training Accuracy:0.909 => Validation Loss: 0.668, Validation Accuracy: 0.900
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 17
# Training Loss: 0.636 , Training Accuracy:0.896 => Validation Loss: 0.647, Validation Accuracy: 0.867
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 18
# Training Loss: 0.625 , Training Accuracy:0.898 => Validation Loss: 0.648, Validation Accuracy: 0.880
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 19
# Training Loss: 0.599 , Training Accuracy:0.900 => Validation Loss: 0.639, Validation Accuracy: 0.867
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 20
# Training Loss: 0.579 , Training Accuracy:0.882 => Validation Loss: 0.622, Validation Accuracy: 0.887
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 21
# Training Loss: 0.569 , Training Accuracy:0.898 => Validation Loss: 0.601, Validation Accuracy: 0.880
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 22
# Training Loss: 0.555 , Training Accuracy:0.902 => Validation Loss: 0.600, Validation Accuracy: 0.893
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 23
# Training Loss: 0.547 , Training Accuracy:0.904 => Validation Loss: 0.578, Validation Accuracy: 0.900
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 24
# Training Loss: 0.532 , Training Accuracy:0.902 => Validation Loss: 0.586, Validation Accuracy: 0.867
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 25
# Training Loss: 0.508 , Training Accuracy:0.924 => Validation Loss: 0.550, Validation Accuracy: 0.920
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 26
# Training Loss: 0.516 , Training Accuracy:0.911 => Validation Loss: 0.540, Validation Accuracy: 0.887
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 27
# Training Loss: 0.496 , Training Accuracy:0.929 => Validation Loss: 0.543, Validation Accuracy: 0.900
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 28
# Training Loss: 0.482 , Training Accuracy:0.922 => Validation Loss: 0.522, Validation Accuracy: 0.920
# 450/450: [==============================>.] - ETA 0.5ss
# Epoch: 29
# Training Loss: 0.471 , Training Accuracy:0.911 => Validation Loss: 0.522, Validation Accuracy: 0.900
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 30
# Training Loss: 0.471 , Training Accuracy:0.920 => Validation Loss: 0.513, Validation Accuracy: 0.900
# Finished Training
# Accuracy of /kaggle/working/covid-19-modelrestnet50-transfer-learning-2.pt on the Test Images: 91 %
# COVID19 - recall :  0.9480519  precision :  0.97333336  accuracy :  0.97333336
# NORMAL - recall :  0.8192771  precision :  0.9066667  accuracy :  0.9022222
# PNEUMONIA - recall :  0.8923077  precision :  0.7733333  accuracy :  0.8933333
# 0.9111111111111111

# %%
for res in results:
    print(f"{res} accuracy: {round(results[res])}%" )
# Out:
# resnet18 accuracy: 90%
# resnet34 accuracy: 88%
# resnet50 accuracy: 86%
# resnet50_data_augmented accuracy: 89%
# restnet50-transfer-learning-1 accuracy: 94%
# restnet50-transfer-learning-2 accuracy: 91%

# %% [markdown]
# **Questions**:
#
# 1. Elaborate on the reason to use pretrained ImageNet weights for transfer learning (instead of training from scratch).
# 2. Which transfer learning approach performs better for finetuning on our dataset? Comment on the possible reasons!
# 3. Explain the best use-cases for ImageNet pretrained weights for the two different approaches (i.e. when it is a good idea to train from scratch OR for finetuning all layers OR for finetuning last layers).

# %% [markdown]
# **ANSWERS:**
#
#
#
# 1. When using a pretrained model the model might converge faster because a good base already exists which reduces the training time. Also, like seen before a small dataset can cause problems and a pretrained model can be trained on a larger dataset which than in turn eliminates the problem of a small dataset.
#
#
#
# 2. The first transfer learning method performed better. A possible reason is that our data differs from the original ImageNet data, thus, modifying the weights of all layers will fit better and yield better results.
#
#
#
# 4. Training from scratch might be better when having a larger dataset to ensure that the model does not overfit. It also could be useful when having images that differ significantly from the ones in ImageNet, so the model can learn the specific features of the data. Finetuning all layers could be useful when dealing with images similar to ImageNet. Finetuning just the last layers can be useul if the training dataset is small.

# %% [markdown]
# **Comment:** When finetuning a model it may also be beneficial to use a different learning rate and change other hyperparameters compared to training from scratch. To keep the exercise simple we do not further explore these options here. If you're interested to investigate these effects you can explore different hyperparameters at the end of the exercise.

# %% [markdown]
# ## RadImageNet
#
# A disadvantage of using ImageNet pretraining for medical images is that the pretraining data is very different to medical images. There are several efforts to build pretraining datasets for the medical image domain, for example [RadImageNet](https://www.radimagenet.com/).
# It contains a pretraining dataset made up of radiology images of a comparable size to ImageNet and provides networks that were pretrained with this dataset.
# - For more details you can check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315).
#
# Note: if you use on RadImageNet weights you will have to use the statistics below for normalization (corresponding to the image statistics of the RadImageNet dataset):
# ```python
# # Normalization: mean and standard deviation values for the pretrained weights on RadImageNet dataset
# radimagenet_mean = (0.223, 0.223, 0.223)
# radimagenet_std = (0.203, 0.203, 0.203)
# ```
#
# We now use pretrained RadImageNet weights for the ResNet50. For this we first need to download those weights and then initialize the architecture correctly. (This is a bit more complex compared to before, so we give you the code for this below.)

# %%
# DO NOT CHANGE
# downloading the RadImageNet pretrained model weights
# RadImageNet weights: https://drive.google.com/file/d/1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR/view
! gdown 1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR

# !unzip -q "/kaggle/working/RadImageNet_pytorch.zip" -d "RadImageNet_Models"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR
# From (redirected): https://drive.google.com/uc?id=1RHt2GnuOYlc_gcoTETtBDSW73mFyRAtR&confirm=t&uuid=d593f0fe-b9ac-4e3d-88a8-65817db9ab62
# To: /kaggle/working/RadImageNet_pytorch.zip
# 100%|█████████████████████████████████████████| 195M/195M [00:00<00:00, 232MB/s]
# replace RadImageNet_Models/RadImageNet_pytorch/DenseNet121.pt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# DO NOT CHANGE
radimagenet_checkpoint_path = "/kaggle/working/RadImageNet_Models/RadImageNet_pytorch"

resnet50_ckpt = torch.load(os.path.join(radimagenet_checkpoint_path, "ResNet50.pt"))
# Out:
# /tmp/ipykernel_30/70626612.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   resnet50_ckpt = torch.load(os.path.join(radimagenet_checkpoint_path, "ResNet50.pt"))

# %%
# DO NOT CHANGE
# We create the backbone to intialize it with the pretrained weights from RadImageNet
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        base_model = torchvision.models.resnet50()
        encoder_layers = list(base_model.children())
        self.backbone = nn.Sequential(*encoder_layers[:9])
                        
    def forward(self, x):
        return self.backbone(x)


# We build the classifier to use the features for transfer learning
class Classifier(nn.Module):
    def __init__(self, num_class):
        super().__init__()
        self.drop_out = nn.Dropout()
        self.linear = nn.Linear(2048, num_class)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.drop_out(x)
        x = self.linear(x)
        return x

# %% [markdown]
# ## Architecture

# %% [markdown]
# We now combine the backbone (ResNet50 pretrained on RadImageNet) and the classification layer for our dataset.
#
# Train and evaluate this model. You can decide whether to finetune the whole model or just the last layer.

# %%
# Let's call the backbone (the encoder excluding the last layers)
backbone = Backbone()

# Loading the pretrained weights to the backbone
backbone.load_state_dict(resnet50_ckpt)
    
# Now let's call the expected fully connected layer
classifier = Classifier(num_class=len(classes))

# Finally, we are ready to build our model 
net = nn.Sequential(backbone, classifier).to(device)

# %%
# Normalizeation: RadImageNet stats

radimagenet_mean = (0.223, 0.223, 0.223)

radimagenet_std = (0.203, 0.203, 0.203)



# Update data transforms for RadImageNet normalization

trans_radimagenet = transforms.Compose([

    transforms.Resize((224, 224)), #size used in paper

    transforms.ToTensor(),

    transforms.Normalize(mean=radimagenet_mean, std=radimagenet_std)

])

train_dataset = datasets.ImageFolder(train_dir, transform=trans_radimagenet)
val_dataset = datasets.ImageFolder(val_dir, transform=trans_radimagenet)
test_dataset = datasets.ImageFolder(test_dir, transform=trans_radimagenet)

# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Train the model

model_name = "radimagenet"

checkpoint_name = f'covid-19-model{model_name}.pt'

checkpoint_path = os.path.join(root_dir, checkpoint_name)


num_epochs = 30



criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.AdamW(net.parameters(), lr=lr)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path, patience=patience)



accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, net, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)



utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses, val_losses, "loss")



net.load_state_dict(torch.load(checkpoint_path, weights_only=True))



correct, total = utils.test_evaluation(net, test_loader, device)

print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))

results[model_name] = 100 * correct / total



cm = utils.get_confusion_matrix(classes, test_loader, net, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)

# HINT:
#    - Training a ResNet50 (updating all / last layers, transfer learning using RadImageNet weights)
#    = (the training workflows are the same as above)
# Out:
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 1
# Training Loss: 1.059 , Training Accuracy:0.424 => Validation Loss: 0.926, Validation Accuracy: 0.767
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 2
# Training Loss: 0.733 , Training Accuracy:0.856 => Validation Loss: 0.575, Validation Accuracy: 0.860
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.376 , Training Accuracy:0.887 => Validation Loss: 0.362, Validation Accuracy: 0.873
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.204 , Training Accuracy:0.929 => Validation Loss: 0.256, Validation Accuracy: 0.920
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.104 , Training Accuracy:0.976 => Validation Loss: 0.276, Validation Accuracy: 0.880
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.070 , Training Accuracy:0.980 => Validation Loss: 0.251, Validation Accuracy: 0.933
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.049 , Training Accuracy:0.989 => Validation Loss: 0.225, Validation Accuracy: 0.900
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.017 , Training Accuracy:1.000 => Validation Loss: 0.220, Validation Accuracy: 0.913
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.009 , Training Accuracy:1.000 => Validation Loss: 0.223, Validation Accuracy: 0.913
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 10
# Training Loss: 0.006 , Training Accuracy:1.000 => Validation Loss: 0.226, Validation Accuracy: 0.920
# EarlyStopping Counter: 2 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 11
# Training Loss: 0.004 , Training Accuracy:1.000 => Validation Loss: 0.228, Validation Accuracy: 0.913
# EarlyStopping Counter: 3 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 12
# Training Loss: 0.003 , Training Accuracy:1.000 => Validation Loss: 0.234, Validation Accuracy: 0.920
# EarlyStopping Counter: 4 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 13
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.236, Validation Accuracy: 0.920
# EarlyStopping Counter: 5 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 14
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.238, Validation Accuracy: 0.920
# EarlyStopping Counter: 6 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 15
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.241, Validation Accuracy: 0.920
# EarlyStopping Counter: 7 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 16
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.245, Validation Accuracy: 0.927
# EarlyStopping Counter: 8 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 17
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.246, Validation Accuracy: 0.927
# EarlyStopping Counter: 9 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 18
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.249, Validation Accuracy: 0.927
# EarlyStopping Counter: 10 out of 10
# Early Stopping...
# Finished Training
# Accuracy of /kaggle/working/covid-19-modelradimagenet.pt on the Test Images: 92 %
# COVID19 - recall :  0.97402596  precision :  1.0  accuracy :  0.9911111
# NORMAL - recall :  0.8815789  precision :  0.8933333  accuracy :  0.92444444
# PNEUMONIA - recall :  0.9027778  precision :  0.8666667  accuracy :  0.92444444
# 0.92

# %%
for res in results:
    print(f"{res} accuracy: {round(results[res])}%" )
# Out:
# resnet18 accuracy: 90%
# resnet34 accuracy: 88%
# resnet50 accuracy: 86%
# resnet50_data_augmented accuracy: 89%
# restnet50-transfer-learning-1 accuracy: 94%
# restnet50-transfer-learning-2 accuracy: 91%
# radimagenet accuracy: 92%

# %% [markdown]
# **Questions**:
#
# 1. Comment on your choice of transfer learning approach (either finetuning last layers / all layers in the model) for RadImageNet? Why could the best approach here be different from ImageNet?

# %% [markdown]
# **Answers**
#
# 1. We tried with both methods and finetuning the whole network resulted in better performance. Although RadImageNet is trained in medical images, these are CT, MRI and US, which have different features than X-Ray, which may be a reason of better performance.

# %% [markdown]
# ### Overall Results:
#
# Update the table with your results for all experiments from the exercise:
#
# | Model    | Training                         | Test Accuracy |
# |:-------: |:--------------------------------:|:-------------:|
# | ResNet18 | from scratch                     |         90    |
# | ResNet34 | from scratch                     |         88    |
# | ResNet50 | from scratch                     |         86    |
# | ResNet50 | from scratch (with augmentation) |         89    |
# | ResNet50 | from ImageNet (all layers)       |         94    |
# | ResNet50 | from ImageNet (last layers)      |         91    |
# | ResNet50 | from RadImageNet                 |         92    |

# %% [markdown]
# **Question**:
# 1. Comment on the trend observed in the results from the table.
# 2. Which is the overall best model? Does this match your expectations? Why/why not?
#
# **Important: Please read the end of the exercise sheet and upload the predictions from your best model, also if you choose not to try out to further improve it.**

# %% [markdown]
# **Answers**
#
# 1. When training from scratch, a deeper network performs worse, which may be due to lack of enough data for a deep network. When adding data augmentation, the results improve a bit, which indicates that the augmentation is useful and leaves the data in the manifold. Finally, finetuning an already trained model, yields the best results.
# 2. The overall best model is finetuning all layers for ImageNet. This does not match our expectations, because RadImageNet should be more adapted to our data, however, we can see that it converges really fast, so we could add some kind of regularization or finetune the network in a more complex manner to improve our results.

# %% [markdown]
# ## Further improve your model (*Optional*)
#
# You can now try to further improve the model by using different architectures or trying some of the advanced training and inference techniques discussed in the lecture. This part of the exercise is optional, and you can try to apply as many approaches for improving your method as you would like. If you don't want to work on the optional part at all please go to the end of the exercise to submit the predictions from your best model.
#
# Here are the aproaches you can try to improve the model:
# 1. Update the training hyperparameter:
#     - You can choose a better initial learning rate, or choose different options for the learning rate scheduler or early stopping.
#     - The most important parameter is probably the learning rate; if you want to improve it then train only for a short time and compare different values. (Remember lecture 2 and the first exercise).
# 2. Try other architectures provided in `torchvision.models`, which implements further CNN architectures (and their respective ImageNet pretrained weights). For example `DenseNet` or `EfficientNet` could yield better results than ResNets.
#     - `torchvision.models` also offers vision transformer architectures (https://arxiv.org/abs/2010.11929). We will cover those later in the lecture, but if you want you can try them here as well. See the snippet at the end of this section for details.
# 3. Try advanced data augmentation strategies, which change the data manifold severly and can boost performance. For example MixUp or CutMix. `torchivsion` already implements them, see [data augmentation with torchvision](https://pytorch.org/vision/stable/transforms.html) for details.
# 4. Try test-time data augmentation. We have covered this idea in the lecture. To use it you don't need to change the training at all, but just update the model prediction during testing. Fot this you can either update the functionality in `ex3_utils.py` or implement a wrapper function or class around the model that implements the test-time data augmentation logic.
# 5. Try model ensembling: combine the predictions of different models on the test set or use an implicit averaging approach like polyak averaging. For this approaches you may need to update the training and/or prediction functions from `ex3_utils.py`.
#
# Here's a snippet that shows how to use vision transformers from torchvision:
#
# ```python
# # replacing the respective layers of the "transformer-based networks" to match our number of classes
# net = torchvision.models.vit_b_16(pretrained=True)
# net.heads.head = nn.Linear(768, num_classes)
# net.to(device)
# ```

# %% [markdown]
# **Hint**: if you want to systematically improve your model you should proceed as follows:
# - Decide on the base architecture and how to initialize it.
#     - Either choose the best model you according to the exercise so far or try if advanced architectures from `torchvision` bring an improvement and continue with one of them.
# - Optimize the training hyperparameters (learning rate, scheduling, early stopping).
# - Investigate advanced techniques:
#   - Training with more or advanced data augmentation.
#   - Test-time data augmentation
#   - Model ensembling
#
# You can divide some of these tasks up among your group and train the best model by combining the best settings you have found for the individual steps.

# %% [markdown]
# ## Train your best model

# %%
from torchvision.transforms import v2

cutmix = v2.CutMix(num_classes=3)
mixup = v2.MixUp(num_classes=3)
cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])

def run_training(
        train_loader, val_loader, net, num_epochs, criterion, optimizer, scheduler=None, early_stopping=None, device="cpu"
):
    """This function runs the training scheme for the training dataset, and validates on the validation dataset as well

    Arguments:
        train_loader: The training dataloader
        val_loader: The validation dataloader
        net: The model architecture to perform the training on
        num_epochs: The total number of epochs to train the models for
        criterion: The loss function
        optimizer: The optimizer object
        scheduler: The learning rate scheduler (the workflow is suited right now for `ReduceLROnPlateau`)
        early_stopping: The early stopping functionality
        device: The torch device

    Returns:
        accuracy: The accuracy on training set
        val_accuracy: The accuracy on validation set
        losses: The losses on training set (per epoch)
        val_losses: The losses on validation set (per epoch)
    """
    accuracy, val_accuracy = [], []
    losses, val_losses = [], []

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_total = 0.0
        num_samples_total = 0.0
        for i, data in enumerate(Bar(train_loader)):
            # getting the training inputs
            inputs, labels = data
            
            images, labels = cutmix_or_mixup(images, labels)
    
            inputs, labels = inputs.to(device), labels.to(device)

            # setting the parameter gradients to zero
            optimizer.zero_grad()

            # forward pass, backward pass, optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # computing accuracy
            _, predicted = torch.max(outputs, 1)
            b_len, corr = get_accuracy(predicted, labels)
            num_samples_total += b_len
            correct_total += corr
            running_loss += loss.item()

        running_loss /= len(train_loader)
        train_accuracy = correct_total / num_samples_total
        val_loss, val_acc = evaluate(net, criterion, val_loader, device)

        if scheduler is not None:
            # decay the learning rate
            if type(scheduler) == torch.optim.lr_scheduler.ReduceLROnPlateau:
                # here, you can potentially track on either of the two metrics: val loss or val accuracy
                scheduler.step(val_loss)
            else:
                scheduler.step()

        print('Epoch: %d' % (epoch + 1))
        print('Training Loss: %.3f , Training Accuracy:%.3f => Validation Loss: %.3f, Validation Accuracy: %.3f ' % (running_loss, train_accuracy, val_loss, val_acc))

        losses.append(running_loss)  # list containing the training losses
        val_losses.append(val_loss)  # list containing the validation losses
        accuracy.append(train_accuracy)  # list containing the training accuracy
        val_accuracy.append(val_acc)  # list containing the validation accuracy

        if early_stopping is not None:
            # early stopping needs to check the validation loss if it decreases, and saves checkpoint of current best model
            early_stopping(val_loss, net)

            if early_stopping.early_stop:
                print("Early Stopping...")
                break

    print('Finished Training')
    return accuracy, val_accuracy, losses, val_losses

# %%
# TODO: YOUR SOLUTIONS HERE
# Finetuning Full Network
train_dataset = datasets.ImageFolder(train_dir, transform=trans)
val_dataset = datasets.ImageFolder(val_dir, transform=trans)
test_dataset = datasets.ImageFolder(test_dir, transform=trans)


# Dataloaders
# TODO: YOUR SOLUTION HERE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

best_model = torchvision.models.densenet121(weights=torchvision.models.DenseNet121_Weights.DEFAULT)

# Let's replace the "fully connected" layer to match our expected output classes

best_model.fc = nn.Linear(2048, 3)

best_model.to(device)



model_name = 'densenet121-transfer-learning'

checkpoint_name = f'covid-19-model{model_name}.pt'

checkpoint_path = os.path.join(root_dir, checkpoint_name)


num_epochs = 100



criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(best_model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path, patience=patience)


accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, best_model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)


utils.get_metric_plots(accuracy, val_accuracy, "accuracy")
utils.get_metric_plots(losses,val_losses, "loss")


best_model.load_state_dict(torch.load(checkpoint_path, weights_only=True))



correct, total = utils.test_evaluation(best_model, test_loader, device)

print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total


cm = utils.get_confusion_matrix(classes, test_loader, best_model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)
# Out:
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 1
# Training Loss: 3.032 , Training Accuracy:0.567 => Validation Loss: 1.079, Validation Accuracy: 0.847
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 2
# Training Loss: 0.501 , Training Accuracy:0.891 => Validation Loss: 0.136, Validation Accuracy: 0.960
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.119 , Training Accuracy:0.956 => Validation Loss: 0.101, Validation Accuracy: 0.967
# 450/450: [==============================>.] - ETA 0.4ss
# Epoch: 4
# Training Loss: 0.141 , Training Accuracy:0.967 => Validation Loss: 0.615, Validation Accuracy: 0.820
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.226 , Training Accuracy:0.927 => Validation Loss: 0.174, Validation Accuracy: 0.947
# EarlyStopping Counter: 2 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.161 , Training Accuracy:0.931 => Validation Loss: 0.247, Validation Accuracy: 0.913
# EarlyStopping Counter: 3 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.124 , Training Accuracy:0.958 => Validation Loss: 0.180, Validation Accuracy: 0.960
# EarlyStopping Counter: 4 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.028 , Training Accuracy:0.991 => Validation Loss: 0.142, Validation Accuracy: 0.947
# EarlyStopping Counter: 5 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.005 , Training Accuracy:1.000 => Validation Loss: 0.132, Validation Accuracy: 0.953
# EarlyStopping Counter: 6 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.143, Validation Accuracy: 0.960
# EarlyStopping Counter: 7 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 11
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.136, Validation Accuracy: 0.967
# EarlyStopping Counter: 8 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 12
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.143, Validation Accuracy: 0.967
# EarlyStopping Counter: 9 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 13
# Training Loss: 0.000 , Training Accuracy:1.000 => Validation Loss: 0.144, Validation Accuracy: 0.967
# EarlyStopping Counter: 10 out of 10
# Early Stopping...
# Finished Training
# Accuracy of /kaggle/working/covid-19-modeldensenet121-transfer-learning.pt on the Test Images: 93 %
# COVID19 - recall :  0.97402596  precision :  1.0  accuracy :  0.9911111
# NORMAL - recall :  0.8875  precision :  0.94666666  accuracy :  0.94222224
# PNEUMONIA - recall :  0.9558824  precision :  0.8666667  accuracy :  0.94222224
# 0.9377777777777778

# %%
def test_evaluation_with_tta(net, test_loader, device, tta_transforms):
    """
    Function to evaluate the model using Test Time Augmentation (TTA).
    Arguments:
    - net: Trained model.
    - test_loader: DataLoader for the test set.
    - device: Device to perform computations ('cpu' or 'cuda').
    - tta_transforms: List of transformations to apply for TTA.
    Returns:
    - correct: Number of correctly predicted labels.
    - total: Total number of labels.
    """
    correct = 0
    total = 0
    net.eval()
    
    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            
            # Collect predictions for all augmentations
            outputs_list = []
            for transform in tta_transforms:
                augmented_images = torch.stack([img for img in images.cpu()])
                augmented_images = augmented_images.to(device)
                outputs = net(augmented_images)
                outputs_list.append(nn.functional.softmax(outputs, dim=1))
            
            # Average predictions across augmentations
            averaged_outputs = torch.mean(torch.stack(outputs_list), dim=0)
            _, predicted = torch.max(averaged_outputs, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    return correct, total

# Example of TTA transforms
tta_transforms = [
    transforms.Compose([transforms.RandomHorizontalFlip(p=1), transforms.ToTensor()]),
    transforms.Compose([transforms.RandomRotation(degrees=15), transforms.ToTensor()]),
    transforms.Compose([transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), transforms.ToTensor()]),
    transforms.Compose([transforms.ColorJitter(brightness=0.2), transforms.ToTensor()]),
    transforms.Compose([transforms.ToTensor()])  # Original image (no augmentation)
]


correct, total = test_evaluation_with_tta(best_model, test_loader, device, tta_transforms)

print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total
# Out:
# Accuracy of /kaggle/working/covid-19-modelrestnet50-transfer-learning-1.pt on the Test Images: 93 %

# %% [markdown]
# ## Submission:
#
# - The `unknown` set corresponds to a hold-out test set (with unlabeled images). Such unseen test data is common in machine learning challenges to ensure an objective comparison of different methods and to test how well these solutions would generalize to real data.
# - Submit the predictons for the `unknown` set using your best model together with your exercise solution.
#     - Upload the solutions to `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results`-> `Tutorial <X>`.
#     - Your submission should be called `results_surname1_surname2_surname3.csv`. The expected file format is described below and we provide a function that generates these results for you already.
# - **Please submit the results from your best model (or the model you expect to perform best). If you don't work on the optional part of the exercise then submit the best result from the models you have trained so far.**
#     - The group with the best submission will get a small prize ;-)
#
# ### Expected Submission Format
#
# Before submitting your results, please make sure that they are in the below mentioned format:
# - `results_<surname1>_<surname2>_<surname3>.csv`
#     - patient_\<ID-1>.jpg | \<CLASS-1>
#     - patient_\<ID-2>.jpg | \<CLASS-2> <br>
#     . <br>
#     . <br>
#     . <br>
#     - patient_\<ID_n>.jpg | \<CLASS-[1-3]>
#
# We have prepared a function that generates these predictions for you (see below).

# %%
for res in results:
    print(f"{res} accuracy: {round(results[res])}%" )
# Out:
# resnet18 accuracy: 90%
# resnet34 accuracy: 88%
# resnet50 accuracy: 86%
# resnet50_data_augmented accuracy: 89%
# restnet50-transfer-learning-1 accuracy: 94%
# restnet50-transfer-learning-2 accuracy: 91%
# radimagenet accuracy: 92%
# densenet121-transfer-learning accuracy: 94%

# %%
# TODO: YOUR SOLUTION HERE
filename = "results.csv"


# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)

# Function generating predictions (in a csv file) for the respective images in the hold-out test set (`unknown` folder)
# Note: if you want to use test-time-augmentation or model ensembling you may need to update this function.
# If you don't want to update it you can also create a new class that implements a wrapper around the model(s)
# that implements the augmentation or ensembling logic.
utils.predict_unknown(best_model, height, width, train_dataset_mean, train_dataset_std, unknown_dir, device, filename)

# Download link is automatically generated for the final results generated
FileLink(filename)
# Out:
# 100%|██████████| 5607/5607 [01:56<00:00, 48.24it/s]
# /kaggle/working/results.csv
