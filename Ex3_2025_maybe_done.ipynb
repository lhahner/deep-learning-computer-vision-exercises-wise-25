# %% [markdown]
# # Exercise Sheet 3 - Covid-19 Classification using Transfer Learning
#
#  * Deep Learning for Computer Vision – Winter Term 2025/26
#  * Lecture by: Constantin Pape
#  * Organizers: Anwai Archit, Sushmita Nair
#  * Tutors: Azhar Akhmetova, Benjamin Eckhardt, Carolin Teuber, Luca Freckmann, Marei Freitag, Oleg Bakumenko, Sarah Muth
#  * Due date: **Tuesday, Dec 9, before 10:00**
# ## Time Required to Solve this Exercise Sheet
#
# As you will train deep CNNs on this exercise sheet, model training will require an increased amount of time. So we recommend to start working on this sheet early.
#
# ## Topic
#
# In this exercise, you will solve an image classification task from medical imaging: classification in Chest X-Ray images into patients with Covid-19, Pneunomia or Healthy. We will use a subset of the dataset from a Kaggle challenge for this. (https://www.kaggle.com/datasets/prashant268/chest-xray-covid19-pneumonia)
#
# The main focus of this exercise is transfer learning and you will approach the classification task with three different approaches:
#
#     Training ResNets from scratch. (Note that we will use the ResNet implementation from torchvision throughout the exercise).
#     Training ResNets pretrained on ImageNet.
#     Training ResNets pretrained on RadImageNet, a large radiology dataset.
#
# In addition you can combine these approaches with other methods to improve the model at the end and upload your best solution on a hold-out test set. This is explained in more details at the end of the exercise.

# %% [markdown]
# ### Hints
#
# In the first part of the exercise you will train ResNets from scratch, analyze the effects of deeper models with small training data and use data augmentations. In the second part, you will solve the same task using pretrained ResNets (from ImageNet - pretrained on natural images; and RadImageNet - pretrained on the medical imaging domain).
#
# To understand the background of this exercise, you can:
# - Review the lectures
#     - Lecture 3 on CNNs
#     - Lecture 4 on Transfer Learning and Augmentaion
# - Check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315 ).
#
# At the end of the exercise you should further improve your model. You can draw upon a number of techniques we discussed for improving model performance. The predictions from your best model on a hold-out test set should be uploaded together with the exercise. More explanation is given at the end of the exercise sheet.
#
# _Do not hesitate to ask questions and ideally discuss them with the fellow students on Matrix! We will monitor the channel to provide you help if your discussions get stuck._

# %% [markdown]
# ## IMPORTANT SUBMISSION INSTRUCTIONS
# - **You need to answer all the questions in written form**
# - When you are done, download the notebook and **rename** it to `<surname1>_<surname2>_<surname3>.ipynb`
# - For the final submission:
#     - Submit the **Jupyter Notebook** (.ipynb file). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Notebook` -> `Tutorial <X>` (where, `X` is the tutorial you are assigned to).
#     - Submit the **Challenge Results** (.csv file) (for the unlabeled images, namely `unknown`). Upload them on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results` -> `Tutorial <X>`
# - Make only one submission of the exercise and results per group.
# - The deadline is strict.
# - You have to present the exercise in the tutorials. We have a high ratio of students to tutors, so please decide which team member presents which part beforehand.
#
# Implementation
# - Do not change the cells which are marked as `DO NOT CHANGE`, similarly write your solution into the cells marked with TODOs and answer the **questions** asked. In addition to the python packages loaded below, you are allowed to use any packages you want.

# %% [markdown]
# **Importing required libraries:**
#
# We have provided the most essential libraries to be used for the exercise. Feel free to add modules as per your requirement.

# %%
# !pip install imageio
# Out:
# Collecting imageio
#   Using cached imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /opt/conda/lib/python3.12/site-packages (from imageio) (11.3.0)
# Using cached imageio-2.37.2-py3-none-any.whl (317 kB)
# Installing collected packages: imageio
# Successfully installed imageio-2.37.2

# %%
import os
from glob import glob
from IPython.display import FileLink

import numpy as np
import imageio.v3 as imageio
import matplotlib.pyplot as plt

import torch
import torchvision
from torch import nn
import torch.optim as optim
import torchvision.transforms as transforms

# %%
# %pip install barbar
# Out:
# Collecting barbar
#   Using cached barbar-0.2.1-py3-none-any.whl.metadata (912 bytes)
# Using cached barbar-0.2.1-py3-none-any.whl (3.9 kB)
# Installing collected packages: barbar
# Successfully installed barbar-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setting up the device (make sure device returns "cuda" to use of the GPUs)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ### Getting the Required Functionalities
#
# We first download and import `ex3_utils.py`, which in which functions for training evaluation etc. are already implemented (similar to the previous exercise). You can download this file and inspect it on your computer to understand the functions it contains.
#
# You can download it from Stud.IP (it's provided there in the same folder as this notebook.)

# %%
# DO NOT CHANGE
import ex3_utils as utils

# %% [markdown]
# ### Data Preparation
#
# The dataset is provided for you in the Project Folder. If you're working on your local machines you can download it as shown below.

# %%
# set a directory to save checkpoints, feel free to change this
root_dir = "./"

# DO NOT CHANGE
# Check if $PROJECT exists
project_path = os.path.expandvars("$PROJECT")

if os.path.exists(project_path):
    # On cluster: use $PROJECT paths
    data_folder = os.path.join(project_path, "data", "Ex3", "covid19")
    model_dir = os.path.join(project_path, "models", "Ex3", "model_weights")
else:
    # Local machine
    data_folder = os.path.join(root_dir, "covid19")
    model_dir = os.path.join(root_dir, "model_weights")
    os.makedirs(model_dir, exist_ok=True)
    # !wget https://owncloud.gwdg.de/index.php/s/dcvhmxtksDDDtK8/download -O covid19-xray.zip 
    # !unzip -q "covid19-xray.zip" -d {data_folder}

print(f"Data folder: {data_folder}")
print(f"Model weights folder: {model_dir}")
# Out:
# Data folder: /projects/scc/UGOE/UXEI/UMIN/scc_umin_pape/scc_umin_pape_dlforcv2526/dir.project/data/Ex3/covid19
# Model weights folder: /projects/scc/UGOE/UXEI/UMIN/scc_umin_pape/scc_umin_pape_dlforcv2526/dir.project/models/Ex3/model_weights

# %% [markdown]
# **Data exploration**
#
# The data is stored in the project folder (or root_dir) and contains four subfolders, namely `train`, `val`, `test` and `unknown` with training / validation / testing split and the hold-out test set, respectively. Each of these (except `unknown`) contains subfolders with the images for the respective classes. As a first step, we will visualize some of the images and labels from the training data.
#
# We will not use the `unknown` directory for training or evaluation, but will only use it for prediction with the best model at the end.

# %%
# DO NOT CHANGE
# Checking the number of classes
train_class_dirs = glob(os.path.join(data_folder, "train", "*"))
val_class_dirs = glob(os.path.join(data_folder, "val", "*"))
test_class_dirs = glob(os.path.join(data_folder, "test", "*"))
assert len(train_class_dirs) == len(val_class_dirs) == len(test_class_dirs) == 3

# %%
# DO NOT CHANGE
# Checking the expected structure of all images
image_paths = glob(os.path.join(data_folder, "**", "*.jpg"), recursive=True)
assert len(image_paths) == (450 + 150 + 225 + 5607), len(image_paths)  # 450 train samples, 150 val samples, 225 test samples, 5607 unlabeled samples (hold-out test)

# %% [markdown]
# Let's plot samples from each class in the training set:

# %%
# Classes available for the task
classes = ["COVID19", "NORMAL", "PNEUMONIA"]
num_classes = 3

# TODO: YOUR SOLUTION HERE
import random

all_image_paths = []

# take images out of folder
for folder in train_class_dirs:
    images = os.listdir(folder)
    all_image_paths.extend([os.path.join(folder, img) for img in images])

# take 16 random ones
selected_paths = random.sample(all_image_paths, 16)

#make 4x4 plot
fig, axes = plt.subplots(4, 4, figsize=(12, 12))

for ax, path in zip(axes.flat, selected_paths):
    img = imageio.imread(path)
    ax.imshow(img)
    ax.axis('off')

    # take class name from parent folder
    class_name = os.path.basename(os.path.dirname(path))
    ax.set_title(class_name, fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# You should see x-ray images from each class and their corresponding labels in their titles. To reflect on our understanding of the dataset, please answer the following **questions**:
# - How many classes are provided in the datasets?
#
# 3 Classes
#
# - Are the images balanced along all the classes in the respective data splits?
#
# It seems there are definitely more images from Covid19 cases than pneumonia and normal cases.

# %% [markdown]
# Let's set the directories for the respective datasets

# %%
# Splits for the dataset 
train_dir = os.path.join(data_folder, "train")
val_dir = os.path.join(data_folder, "val")
test_dir = os.path.join(data_folder, "test")
unknown_dir = os.path.join(data_folder, "unknown")

print("Train dir:", train_dir)
print("Classes:", classes)
print(os.listdir(train_dir))
results = dict()
# Out:
# Train dir: /projects/scc/UGOE/UXEI/UMIN/scc_umin_pape/scc_umin_pape_dlforcv2526/dir.project/data/Ex3/covid19/train
# Classes: ['COVID19', 'NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA', 'COVID19']

# %% [markdown]
# Now, we obtain the statistics (mean and standard deviation) from the training dataset to be used for normalizing the datasets

# %%
# DO NOT CHANGE
train_images = []
for class_name in classes:
    train_images.extend(glob(os.path.join(train_dir, class_name, "*.jpg")))


to_tensor = torchvision.transforms.ToTensor()
imgs = torch.stack([to_tensor(imageio.imread(im)) for im in train_images])
print(imgs.shape)

# And then compute the mean and standard deviation independently for the image channels.
# (The channels are stored in dim=1, by excluding this below we achieve this.)
mean = torch.mean(imgs, dim=(0, 2, 3))
std = torch.std(imgs, dim=(0, 2, 3))

# Delete the images again in order to save memory.
del imgs

print(mean)
print(std)
# Out:
# torch.Size([450, 3, 512, 512])
# tensor([0.4949, 0.4952, 0.4957])
# tensor([0.2298, 0.2298, 0.2298])

# %%
train_dataset_mean = mean
train_dataset_std = std

# %% [markdown]
# **Implement PyTorch dataloader**
#
# As a next step, we implement a `torch.utils.data.Dataset` followed by the `torch.utils.data.DataLoader` to have access to our data during training, validation and testing. In our case, the data is stored in a format that is already compatible with `torchvision.datasets.ImageFolder`.

# %% [markdown]
# To use the image data in PyTorch it first needs to be transformed. You can use the transformations from [torchvision.transforms](https://pytorch.org/vision/0.9/transforms.html) for this. Here, we need to:
# - Convert the image data to a `torch.tensor` (`transforms.ToTensor`)
# - Standardize the inputs based on their data statistics (`transforms.Normalize`)
# - Resize the images (`transforms.Resize`). Note that resizing is not strictly necessary, but will speed up training and resize the images to a size that better matches the ImageNet pretraining data.
#
# To combine several transforms together, you can use `torchvision.transforms.Compose` by passing the list of 'transform' objects to compose.

# %%
# We resize the images to the size 256 x 256 to speed up training
height = width = 256

# Get the usual transforms to have the inputs from dataloaders as expected
def get_transforms(height, width):
    # TODO: YOUR CODE HERE
    transform = transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize(train_dataset_mean,train_dataset_std), 
        transforms.Resize(height)
    ])
    return transform

# %%
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

# Datasets
# TODO: YOUR SOLUTION HERE

from torchvision import datasets

train_dataset = datasets.ImageFolder(train_dir, transform=get_transforms(height,width))
val_dataset = datasets.ImageFolder(val_dir, transform=get_transforms(height,width))
test_dataset = datasets.ImageFolder(test_dir, transform=get_transforms(height,width))

# Dataloaders
# TODO: YOUR SOLUTION HERE

from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Now let's visualize the images after transformation as they are returned from the training loader.

# %%
# Function to show images
fig = plt.figure(figsize=(10, 15))
def imshow(img):
    img = img / 2 + 0.5  # unnormalise
    npimg = img.numpy()
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# Obtain random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Show the images
imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s, ' % classes[labels[j]] for j in range(len(labels))))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.57825315..1.5991571].
# PNEUMONIA,  PNEUMONIA,  COVID19,  PNEUMONIA,  PNEUMONIA,  NORMAL,  NORMAL,  PNEUMONIA,  COVID19,  COVID19,  PNEUMONIA,  COVID19,  COVID19,  COVID19,  NORMAL,  NORMAL,

# %% [markdown]
# ## Architecture
#
# We will use the ResNet implementation from torchvision, see https://pytorch.org/vision/stable/models.html, for this exercise.
#
# - We start with the smallest ResNet model, the ResNet18 (https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - And will then use deeper ResNets to explore how well larger models can be trained on a small dataset.
# - To use random weight initialization (in order to train from scratch), you can just create models without passing additional arguments like so: `torchvision.models.<MODEL_NAME>()`.

# %% [markdown]
# We need to adapt the model to fit with our purpose. For this, we must change the output dimension of the last fully-connected layer to consider the number of classes in our problem. Let's check the last layer out.

# %%
# Let's get the resnet18 architecture and understanding the backbone (in order to adapt it to our problem)
# TODO: YOUR SOLUTION HERE
model = torchvision.models.resnet18()
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# We see above that there is a component called `fc` that consists of a `Linear` layer. To make use of ResNet18 for our classification task, we need to change the `out_features` of the linear layer to the number of classes of our problem. In our case, it's `num_classes` (=3).

# %%
print(model.fc)
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %% [markdown]
# To replace the last layer (classification layer) you can use the following code. (Here we provide a stand-alone code snippet)
#
# ```python
# import torchvision
# import torch.nn as nn
#
# model = torchvision.models.resnet18()
#
# # Let's replace the "fully connected" layer to match our expected output classes
# model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
# model.to(device)
# ```

# %%
# Replacing the last layer(s) of ResNet18 to match our number of classes
# TODO: YOUR SOLUTION HERE
model = torchvision.models.resnet18()
model.fc = nn.Linear(512, 3)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet18'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet18-from-scratch.pt

# %% [markdown]
# If you now display the model (using `print(model)`) you should see that its last layer has been updated.

# %% [markdown]
# ### Training
#
# Let's train the model for 10 epochs, using the `Adam` optimizer, `CrossEntropyLoss` as the criterion (loss function) and a learning rate scheduler (e.g. `ReduceLROnPlateau`).

# %%
# Clearing the GPU cache
torch.cuda.empty_cache()
print("Starting training from scratch with network: ", model_name)

# TODO: YOUR SOLUTION HERE
# Optimizer and loss configurations
lr=0.001
patience=10
num_epochs=10

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)  # learning rate scheduler

# Initializing the early stopping of the training
early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

# HINT: open the 'ex3_utils.py' file to understand the arguments of 'run_training'
accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)
# Out:
# Starting training from scratch with network:  resnet18
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 1
# Training Loss: 0.801 , Training Accuracy:0.718 => Validation Loss: 1.562, Validation Accuracy: 0.620
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 2
# Training Loss: 1.336 , Training Accuracy:0.573 => Validation Loss: 0.796, Validation Accuracy: 0.540
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 3
# Training Loss: 0.753 , Training Accuracy:0.649 => Validation Loss: 0.954, Validation Accuracy: 0.487
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 4
# Training Loss: 0.764 , Training Accuracy:0.616 => Validation Loss: 0.795, Validation Accuracy: 0.687
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 5
# Training Loss: 0.729 , Training Accuracy:0.680 => Validation Loss: 0.947, Validation Accuracy: 0.620
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 6
# Training Loss: 0.710 , Training Accuracy:0.660 => Validation Loss: 0.770, Validation Accuracy: 0.653
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 7
# Training Loss: 0.664 , Training Accuracy:0.684 => Validation Loss: 0.844, Validation Accuracy: 0.540
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 8
# Training Loss: 0.624 , Training Accuracy:0.691 => Validation Loss: 0.716, Validation Accuracy: 0.607
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 9
# Training Loss: 0.543 , Training Accuracy:0.736 => Validation Loss: 0.774, Validation Accuracy: 0.573
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 10
# Training Loss: 0.559 , Training Accuracy:0.720 => Validation Loss: 0.747, Validation Accuracy: 0.693
# EarlyStopping Counter: 2 out of 10
# Finished Training

# %% [markdown]
# Now, let's see how the accuracy and loss plots look for our training.

# %%
# Training and validation accuracy plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(accuracy, val_accuracy, "accuracy")


# Training and validation loss plots
# TODO: YOUR SOLUTION HERE
utils.get_metric_plots(losses,val_losses, "loss")

# %% [markdown]
# ### Evaluation on the test set
#
# Let's check the test accuracy and confusion matrix. All the required functionality is already provided in `ex3_utils.py` and you just need to read the corresponding functions to understand how to call them here.

# %%
# Loading the best model for inference (NOTE: you should load the checkpoints to the expected model architecture, else you might get some mismatch errors)
# TODO: YOUR SOLUTION HERE
model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

# Provide the testing dataset wrapped in a dataloader to check for inference
# TODO: YOUR SOLUTION HERE
correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))

results[model_name] = 100 * correct / total
# Out:
# Accuracy of ./covid-19-resnet18-from-scratch.pt on the Test Images: 70 %

# %%
# Get the confusion matrix for the test dataset
# TODO: YOUR SOLUTION HERE
cm = utils.get_confusion_matrix(classes, test_loader,model, device)


# See the precision, recall and accuracy per class for the test dataset
# TODO: YOUR SOLUTION HERE
utils.check_precision_recall_accuracy(cm, classes)
# Out:
# COVID19 - recall :  0.875  precision :  0.84  accuracy :  0.9066667
# NORMAL - recall :  0.71875  precision :  0.61333334  accuracy :  0.7911111
# PNEUMONIA - recall :  0.56179774  precision :  0.6666667  accuracy :  0.71555555

# %%
# Check the confusion matrix heatmap to visually see the evaluation on the test set
# TODO: YOUR SOLUTION HERE
utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# 0.7066666666666667

# %% [markdown]
# Now let's try training deeper ResNet architectures using the same hyperparameters from above:
# - Train and evaluate a ResNet34 from scratch.
# - Train and evaluate a ResNet50 from scratch.

# %% [markdown]
# ## ResNet 34

# %%
# TODO: YOUR SOLUTIONS HERE
torch.cuda.empty_cache()

# ResNet34
model = torchvision.models.resnet34()
model.fc = nn.Linear(512, 3)
model.to(device)


# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet34'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# HINT: (for the workflow)
#    - Start with training a ResNet34:
#          - Updating the last layers (training the network from scratch)
#          - REMEMBER: Save the respective checkpoints uniquely, and initialize the early stopping with them.
#          - Use the expected hyperparameters for training
#          - Observe the loss and accuracy curves for training and validation
#    - Next, train a ResNet50 (following the same suggestion as above)
#    - Finally, evaluate both the trained models from above on the test set and answer the questions.
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet34-from-scratch.pt
# Starting training from scratch with network:  resnet34
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 1
# Training Loss: 0.814 , Training Accuracy:0.704 => Validation Loss: 3.346, Validation Accuracy: 0.400
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 2
# Training Loss: 1.750 , Training Accuracy:0.342 => Validation Loss: 1.209, Validation Accuracy: 0.333
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 3
# Training Loss: 1.131 , Training Accuracy:0.367 => Validation Loss: 1.134, Validation Accuracy: 0.333
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 4
# Training Loss: 1.110 , Training Accuracy:0.362 => Validation Loss: 1.102, Validation Accuracy: 0.387
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 5
# Training Loss: 1.043 , Training Accuracy:0.447 => Validation Loss: 1.054, Validation Accuracy: 0.447
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 6
# Training Loss: 0.856 , Training Accuracy:0.520 => Validation Loss: 0.911, Validation Accuracy: 0.600
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 7
# Training Loss: 0.704 , Training Accuracy:0.580 => Validation Loss: 0.952, Validation Accuracy: 0.507
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 8
# Training Loss: 0.711 , Training Accuracy:0.613 => Validation Loss: 0.829, Validation Accuracy: 0.573
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 9
# Training Loss: 0.674 , Training Accuracy:0.638 => Validation Loss: 0.738, Validation Accuracy: 0.680
# 450/450: [==============================>.] - ETA 0.1s
# Epoch: 10
# Training Loss: 0.716 , Training Accuracy:0.667 => Validation Loss: 0.827, Validation Accuracy: 0.560
# EarlyStopping Counter: 1 out of 10
# Finished Training
# Accuracy of ./covid-19-resnet34-from-scratch.pt on the Test Images: 68 %
# COVID19 - recall :  0.92957747  precision :  0.88  accuracy :  0.93777776
# NORMAL - recall :  0.5413534  precision :  0.96  accuracy :  0.71555555
# PNEUMONIA - recall :  0.8095238  precision :  0.22666667  accuracy :  0.72444445
# 0.6888888888888889

# %% [markdown]
# ## ResNet50

# %%
torch.cuda.empty_cache()

# ResNet50
model = torchvision.models.resnet50()
model.fc = nn.Linear(2048, 3)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet50'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet50-from-scratch.pt
# Starting training from scratch with network:  resnet50
# 450/450: [==============================>.] - ETA 1.2ss
# Epoch: 1
# Training Loss: 0.833 , Training Accuracy:0.671 => Validation Loss: 3.354, Validation Accuracy: 0.367
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 2
# Training Loss: 7.908 , Training Accuracy:0.376 => Validation Loss: 1.035, Validation Accuracy: 0.453
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.920 , Training Accuracy:0.582 => Validation Loss: 1.364, Validation Accuracy: 0.400
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.933 , Training Accuracy:0.578 => Validation Loss: 0.799, Validation Accuracy: 0.613
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.728 , Training Accuracy:0.678 => Validation Loss: 0.795, Validation Accuracy: 0.580
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.717 , Training Accuracy:0.616 => Validation Loss: 0.809, Validation Accuracy: 0.627
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.677 , Training Accuracy:0.691 => Validation Loss: 0.738, Validation Accuracy: 0.707
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.618 , Training Accuracy:0.704 => Validation Loss: 0.808, Validation Accuracy: 0.633
# EarlyStopping Counter: 1 out of 10
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.638 , Training Accuracy:0.687 => Validation Loss: 0.691, Validation Accuracy: 0.680
# 450/450: [==============================>.] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.643 , Training Accuracy:0.722 => Validation Loss: 0.686, Validation Accuracy: 0.733
# Finished Training
# Accuracy of ./covid-19-resnet50-from-scratch.pt on the Test Images: 77 %
# COVID19 - recall :  0.8072289  precision :  0.8933333  accuracy :  0.8933333
# NORMAL - recall :  0.7128713  precision :  0.96  accuracy :  0.8577778
# PNEUMONIA - recall :  0.85365856  precision :  0.46666667  accuracy :  0.79555553
# 0.7733333333333333

# %% [markdown]
# **Questions**:
#
# 1. How does the performance of the three architectures compare to each other? Are there any specific patterns you can see in the confusion matrices?
# 2. Is there a correlation between the dataset size and depth of the network?
# 3. Given these observations, which model would you prefer for training on a small dataset from scratch?

# %% [markdown]
# ANSWER:
#
# 1. The performance is the best for the ResNet18. It returned the highest test accuracy. The accuracy plot shows some fluctuation but it is overall increasing. The loss plot shows low values for the loss. The confusion matrix has high values in the diagonal from upper left to lower right corner and lower values in the other corners. The same structure holds for the other models but for the ResNet18 the values are more extreme. The ResNet34 is the second best and the ResNet50 performs the worst which can be seen in the plots, the test accuracy, and the confusion matrix with the same reasons as mentioned before.
# 3. The dataset is pretty small with only 450 images. The models perform worse the larger they get. So probably yes, there could be a correlation between the size of the dataset and the depth of the network. Deep networks tend more easily to overfit when trained on small datasets. This aligns with the plot for the losses of the ResNet50 which shows small signs of overfitting.
# 4. Probably the ResNet18 is the best because it returns the highest test accuracy and the plots look like they are wished to. If the dataset is a little bit bigger also the ResNet34 still works good and could be an even better choice.

# %% [markdown]
# #### Now let's try with **Data Augmentation**
#
# A common strategy when dealing with small datasets is to add data augmentations.
#
# Let's try a few augmentations from [torchvision.transforms](https://pytorch.org/vision/main/transforms.html) that do not significantly distort the data (stay on the data manifold) and train a ResNet50. Here, we want to see if augmentations allow us to train deeper CNNs.
# Common augmentations for data augmentation are:
# - flipping the inputs along the axes.
# - changing the brightness, contrast and saturation of the inputs.
# - adding small noise to the input.
#
# You can try different combinations of augmentations here. You can add augmentations by updating the `transform` passed to the train dataset. You can again use `Compose` to chain augmentations. Play around with different augmentations here but if you can not find any data augmentations that improve model performance, move on to the next task.
#
# Note; you should only introduce augmentation for the training and validation datasets, **not** for the test dataset. Otherwise the evaluation between models is not consistent anymore.

# %%
# TODO: YOUR SOLUTIONS HERE

def get_transforms_augmentation(height, width):

    # TODO: YOUR CODE HERE
    transform = transforms.Compose([
        # Data Augmentations
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(10),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)), 
        transforms.Resize((height, width)),
        transforms.ToTensor(),
        transforms.Normalize(train_dataset_mean,train_dataset_std)
    ])

    return transform

# HINT:
#    - Training a ResNet50 (incorporating data augmentation strategies)
#    = (the training workflows are the same as above)

# %% [markdown]
# We need to apply the new transforms to the dataset and then use our dataloader. Let's reuse our scripts from above, now with the added data augmentation strategies.

# %%
from torch.utils.data import ConcatDataset

transform_data_augmentation = get_transforms_augmentation(256,256)

# Datasets
train_dataset_augmented = datasets.ImageFolder(train_dir, transform=transform_data_augmentation)
val_dataset_augmented = datasets.ImageFolder(val_dir, transform=transform_data_augmentation)

# Combine the datasets using ConcatDataset
full_train_dataset = ConcatDataset([train_dataset, train_dataset_augmented])
full_val_dataset = ConcatDataset([val_dataset, val_dataset_augmented])

# Dataloaders
train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(full_val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Now, we are ready to train the ResNet50 with data augmentations. Let's train for longer (30 epochs) here, with the same hyperparameters as before, and evaluate the model on the test set.

# %%
# TODO: YOUR SOLUTION HERE
torch.cuda.empty_cache()

# ResNet50
model = torchvision.models.resnet50()
model.fc = nn.Linear(2048, 3)
model.to(device)

# Let's define the checkpoint name where the specific model checkpoint will be saved
model_name = 'resnet50_data_augmented'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)

num_epochs = 30

accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, t"loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correc / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet50_data_augmented-from-scratch.pt
# Starting training from scratch with network:  resnet50_data_augmented
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 1
# Training Loss: 0.942 , Training Accuracy:0.653 => Validation Loss: 1.502, Validation Accuracy: 0.600
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 2
# Training Loss: 1.269 , Training Accuracy:0.347 => Validation Loss: 1.103, Validation Accuracy: 0.333
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 3
# Training Loss: 1.106 , Training Accuracy:0.359 => Validation Loss: 1.095, Validation Accuracy: 0.373
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 4
# Training Loss: 1.096 , Training Accuracy:0.356 => Validation Loss: 1.072, Validation Accuracy: 0.447
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 5
# Training Loss: 1.097 , Training Accuracy:0.384 => Validation Loss: 1.089, Validation Accuracy: 0.333
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 6
# Training Loss: 1.082 , Training Accuracy:0.384 => Validation Loss: 1.053, Validation Accuracy: 0.370
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.983 , Training Accuracy:0.487 => Validation Loss: 0.941, Validation Accuracy: 0.600
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.957 , Training Accuracy:0.501 => Validation Loss: 0.959, Validation Accuracy: 0.510
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.835 , Training Accuracy:0.608 => Validation Loss: 0.958, Validation Accuracy: 0.607
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.807 , Training Accuracy:0.621 => Validation Loss: 0.800, Validation Accuracy: 0.617
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 11
# Training Loss: 0.756 , Training Accuracy:0.641 => Validation Loss: 0.777, Validation Accuracy: 0.593
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 12
# Training Loss: 0.723 , Training Accuracy:0.658 => Validation Loss: 1.144, Validation Accuracy: 0.477
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 13
# Training Loss: 0.611 , Training Accuracy:0.724 => Validation Loss: 0.622, Validation Accuracy: 0.750
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 14
# Training Loss: 0.499 , Training Accuracy:0.813 => Validation Loss: 0.539, Validation Accuracy: 0.820
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 15
# Training Loss: 0.455 , Training Accuracy:0.819 => Validation Loss: 0.614, Validation Accuracy: 0.797
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 16
# Training Loss: 0.443 , Training Accuracy:0.822 => Validation Loss: 0.538, Validation Accuracy: 0.813
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 17
# Training Loss: 0.435 , Training Accuracy:0.838 => Validation Loss: 0.659, Validation Accuracy: 0.753
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 18
# Training Loss: 0.431 , Training Accuracy:0.847 => Validation Loss: 0.469, Validation Accuracy: 0.823
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 19
# Training Loss: 0.391 , Training Accuracy:0.852 => Validation Loss: 0.484, Validation Accuracy: 0.837
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 20
# Training Loss: 0.356 , Training Accuracy:0.861 => Validation Loss: 0.478, Validation Accuracy: 0.803
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 21
# Training Loss: 0.317 , Training Accuracy:0.877 => Validation Loss: 0.464, Validation Accuracy: 0.833
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 22
# Training Loss: 0.312 , Training Accuracy:0.891 => Validation Loss: 0.616, Validation Accuracy: 0.770
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 23
# Training Loss: 0.316 , Training Accuracy:0.881 => Validation Loss: 0.514, Validation Accuracy: 0.817
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 24
# Training Loss: 0.297 , Training Accuracy:0.888 => Validation Loss: 0.458, Validation Accuracy: 0.820
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 25
# Training Loss: 0.301 , Training Accuracy:0.890 => Validation Loss: 0.450, Validation Accuracy: 0.817
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 26
# Training Loss: 0.268 , Training Accuracy:0.898 => Validation Loss: 0.407, Validation Accuracy: 0.847
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 27
# Training Loss: 0.238 , Training Accuracy:0.924 => Validation Loss: 0.413, Validation Accuracy: 0.870
# EarlyStopping Counter: 1 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 28
# Training Loss: 0.293 , Training Accuracy:0.893 => Validation Loss: 0.520, Validation Accuracy: 0.817
# EarlyStopping Counter: 2 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 29
# Training Loss: 0.242 , Training Accuracy:0.907 => Validation Loss: 0.427, Validation Accuracy: 0.827
# EarlyStopping Counter: 3 out of 10
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 30
# Training Loss: 0.246 , Training Accuracy:0.906 => Validation Loss: 0.474, Validation Accuracy: 0.857
# EarlyStopping Counter: 4 out of 10
# Finished Training
# Accuracy of ./covid-19-resnet50_data_augmented-from-scratch.pt on the Test Images: 88 %
# COVID19 - recall :  0.93670887  precision :  0.9866667  accuracy :  0.97333336
# NORMAL - recall :  0.84615386  precision :  0.88  accuracy :  0.9066667
# PNEUMONIA - recall :  0.86764705  precision :  0.7866667  accuracy :  0.8888889
# 0.8844444444444445

# %% [markdown]
# **Questions**:
#
# 1. Does the effect of data augmentation match your expectation?
# 2. Are there other kinds of data augmentation that would make sense for this dataset? Think about augmentations that "leave the data manifold".

# %% [markdown]
# **Answers**
#
# 1. Yes, the model returns slightly better results. The test accuracy is a little higher and less signs for overfitting occur in the plots. Also the values of the confusion matrix look a little better. The changes are low so far but the performance increased a little bit because the size of the dataset increased with the data augmentation.
#
# 2. Other kinds of transformations that fit the dataset and leave the data in the manifold could be the ones that we used, like slightly rotating or translating vertically or horizontally the images (to simulate different postures of the patients).

# %% [markdown]
# ## ImageNet
#
# The [ImageNet project](https://www.image-net.org/) provides a large-scale dataset with natural images. There exist different version of this dataset, the largest using 14 million annotated images for image classification with over 20,000 categories.
#
# This dataset has been used by the ImageNet Scale Visual Recognition Challenge ([ILSVRC](https://image-net.org/challenges/LSVRC/#:~:text=The%20ImageNet%20Large%20Scale%20Visual,image%20classification%20at%20large%20scale.)) to benchmark classification algorithms competing to improve classification. The version fo the dataset used for this classification contains a million training images with 1,000 categeories (and corresponds to the version fo the dataset we discussed in the lecture).
#
# `torchvision.models` has a pool of neural networks, for which pretrained ImageNet weights are also available. To make use of pretrained models, we need to preprocess the images based on the mean and standard deviation of ImageNet (this step is critical!). The statistics for ImageNet are provided [here](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet50.html#:~:text=1.0%5D%20and%20then-,normalized%20using%20mean%3D%5B0.485%2C%200.456%2C%200.406%5D%20and%20std%3D%5B0.229%2C%200.224%2C%200.225%5D.,-Next).
#
# ### ImageNet transfer learning for ResNet50
#
# We will now check if transfer learning from ImageNet leads to improvements for our dataset. Here, we will focus on the ResNet50 as we have seen before that without transfer learning its performance is worse compared to smaller architectures for our dataset.
#
# There are two different approaches for how we can fine-tune a CNN initialized with pretrained weights:
# 1. Update the weights for all layers of the network. For this approach we initialize with pretrained weights but otherwise train the network as before. See this code snippet:
#
#     ```python
#     model_dir = "./model_weights"
#     weights_path = os.path.join(model_dir, "resnet50-0676ba61.pth")
#
#     model = torchvision.models.resnet50(weights=None)  # or pretrained=False in older torchvision
#
#     # Load the state dictionary
#     state_dict = torch.load(weights_path, map_location=device)
#     model.load_state_dict(state_dict)
#     # Let's replace the "fully connected" layer to match our expected output classes
#     model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
#     model.to(device)
#
#     # Train the network as usual
#     ```
#
#     or if you are not using Jupyter HPC:
#
#     ```python
#     import torchvision
#     import torch.nn as nn
#
#     model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
#     # Let's replace the "fully connected" layer to match our expected output classes
#     model.fc = nn.Linear(<INPUT_FEATURES>, <OUTPUT_CLASSES>)
#     model.to(device)
#
#     # Train the network as usual
#     ```
#
# 2. Only update the weights of the last layer (classification layer). In this case we would "freeze" the pretrained network and use it as a fixed feature extractor. This is achieved by disabling parameter updates for all but the last layer of the network.
#
# We will start with the first approach (fine-tuning the full network).

# %%
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

from torchvision import datasets
from torch.utils.data import DataLoader

mean=[0.485, 0.456, 0.406] 
std=[0.229, 0.224, 0.225]

train_dataset_mean,train_dataset_std = mean,std

transform_data_augmentation = get_transforms_augmentation(256,256)

train_dataset_augmented = datasets.ImageFolder(train_dir, transform=transform_data_augmentation)
val_dataset_augmented = datasets.ImageFolder(val_dir, transform=transform_data_augmentation)

train_dataset = datasets.ImageFolder(train_dir, transform=get_transforms(height,width))
val_dataset = datasets.ImageFolder(val_dir, transform=get_transforms(height,width))
full_train_dataset = ConcatDataset([train_dataset, train_dataset_augmented])
full_val_dataset = ConcatDataset([val_dataset, val_dataset_augmented])

# Dataloaders
train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(full_val_dataset, batch_size=batch_size, shuffle=False)



test_dataset = datasets.ImageFolder(test_dir, transform=get_transforms(height,width))


test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)
from torchvision.models import resnet50, ResNet50_Weights

model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
model.fc =  nn.Linear(2048, 3)
model.to(device)

lr=0.0001
patience=30
num_epochs=30






# Train the network as usual

model_name = 'resnet50_pretrained'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = None #optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)




accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet50_pretrained-from-scratch.pt
# Starting training from scratch with network:  resnet50_pretrained
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 1
# Training Loss: 0.531 , Training Accuracy:0.856 => Validation Loss: 0.207, Validation Accuracy: 0.927
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 2
# Training Loss: 0.362 , Training Accuracy:0.881 => Validation Loss: 0.430, Validation Accuracy: 0.860
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 3
# Training Loss: 0.232 , Training Accuracy:0.916 => Validation Loss: 0.459, Validation Accuracy: 0.810
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 4
# Training Loss: 0.136 , Training Accuracy:0.949 => Validation Loss: 0.140, Validation Accuracy: 0.940
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 5
# Training Loss: 0.108 , Training Accuracy:0.966 => Validation Loss: 0.188, Validation Accuracy: 0.930
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 6
# Training Loss: 0.206 , Training Accuracy:0.933 => Validation Loss: 0.224, Validation Accuracy: 0.923
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 7
# Training Loss: 0.079 , Training Accuracy:0.966 => Validation Loss: 0.170, Validation Accuracy: 0.947
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 8
# Training Loss: 0.052 , Training Accuracy:0.979 => Validation Loss: 0.186, Validation Accuracy: 0.943
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 9
# Training Loss: 0.145 , Training Accuracy:0.949 => Validation Loss: 0.175, Validation Accuracy: 0.937
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 10
# Training Loss: 0.042 , Training Accuracy:0.983 => Validation Loss: 0.239, Validation Accuracy: 0.947
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 11
# Training Loss: 0.055 , Training Accuracy:0.973 => Validation Loss: 0.245, Validation Accuracy: 0.927
# EarlyStopping Counter: 7 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 12
# Training Loss: 0.051 , Training Accuracy:0.988 => Validation Loss: 0.202, Validation Accuracy: 0.940
# EarlyStopping Counter: 8 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 13
# Training Loss: 0.048 , Training Accuracy:0.984 => Validation Loss: 0.167, Validation Accuracy: 0.957
# EarlyStopping Counter: 9 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 14
# Training Loss: 0.021 , Training Accuracy:0.992 => Validation Loss: 0.290, Validation Accuracy: 0.933
# EarlyStopping Counter: 10 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 15
# Training Loss: 0.030 , Training Accuracy:0.991 => Validation Loss: 0.184, Validation Accuracy: 0.953
# EarlyStopping Counter: 11 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 16
# Training Loss: 0.013 , Training Accuracy:0.993 => Validation Loss: 0.388, Validation Accuracy: 0.923
# EarlyStopping Counter: 12 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 17
# Training Loss: 0.020 , Training Accuracy:0.998 => Validation Loss: 0.257, Validation Accuracy: 0.937
# EarlyStopping Counter: 13 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 18
# Training Loss: 0.026 , Training Accuracy:0.987 => Validation Loss: 0.160, Validation Accuracy: 0.947
# EarlyStopping Counter: 14 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 19
# Training Loss: 0.015 , Training Accuracy:0.996 => Validation Loss: 0.174, Validation Accuracy: 0.967
# EarlyStopping Counter: 15 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 20
# Training Loss: 0.045 , Training Accuracy:0.983 => Validation Loss: 0.299, Validation Accuracy: 0.880
# EarlyStopping Counter: 16 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 21
# Training Loss: 0.038 , Training Accuracy:0.988 => Validation Loss: 0.554, Validation Accuracy: 0.870
# EarlyStopping Counter: 17 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 22
# Training Loss: 0.048 , Training Accuracy:0.988 => Validation Loss: 0.193, Validation Accuracy: 0.940
# EarlyStopping Counter: 18 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 23
# Training Loss: 0.024 , Training Accuracy:0.990 => Validation Loss: 0.095, Validation Accuracy: 0.973
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 24
# Training Loss: 0.019 , Training Accuracy:0.993 => Validation Loss: 0.220, Validation Accuracy: 0.937
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 25
# Training Loss: 0.003 , Training Accuracy:0.999 => Validation Loss: 0.180, Validation Accuracy: 0.960
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 26
# Training Loss: 0.066 , Training Accuracy:0.980 => Validation Loss: 0.208, Validation Accuracy: 0.947
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 27
# Training Loss: 0.102 , Training Accuracy:0.953 => Validation Loss: 0.164, Validation Accuracy: 0.927
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 28
# Training Loss: 0.024 , Training Accuracy:0.988 => Validation Loss: 0.212, Validation Accuracy: 0.930
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 29
# Training Loss: 0.004 , Training Accuracy:1.000 => Validation Loss: 0.380, Validation Accuracy: 0.940
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 30
# Training Loss: 0.082 , Training Accuracy:0.972 => Validation Loss: 0.288, Validation Accuracy: 0.927
# EarlyStopping Counter: 7 out of 30
# Finished Training
# Accuracy of ./covid-19-resnet50_pretrained-from-scratch.pt on the Test Images: 93 %
# COVID19 - recall :  1.0  precision :  1.0  accuracy :  1.0
# NORMAL - recall :  0.86585367  precision :  0.94666666  accuracy :  0.93333334
# PNEUMONIA - recall :  0.9411765  precision :  0.85333335  accuracy :  0.93333334
# 0.9333333333333333

# %% [markdown]
# Now let's try the second approach and finetune only the last layer.
#
# By default all parameters of a network will be updated by gradient descent. The gradient updates can be disabled by setting `requires_grad = False`. So in order to finetune only the last layer you need to `requires_grad = False` for all other layers in the network.
#
# You can see how the parameters are disabled for a complete model in the code snippet below. For the next exercise you need to make sure that `requires_grad` stays `True` for the last layer!
#
# ```python
# for param_name, param in model.named_parameters():
#     param.requires_grad = False
# ```

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating the last layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)



model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
for param_name, param in model.named_parameters():
    param.requires_grad = False

#new layer req grad per default
model.fc =  nn.Linear(2048, 3)

model.to(device)

lr=0.0001
patience=30
num_epochs=30






# Train the network as usual

model_name = 'resnet50_pretrained_last_layer'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = None#optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)




accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet50_pretrained_last_layer-from-scratch.pt
# Starting training from scratch with network:  resnet50_pretrained_last_layer
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 1
# Training Loss: 1.046 , Training Accuracy:0.522 => Validation Loss: 0.976, Validation Accuracy: 0.563
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 2
# Training Loss: 0.907 , Training Accuracy:0.809 => Validation Loss: 0.861, Validation Accuracy: 0.867
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 3
# Training Loss: 0.790 , Training Accuracy:0.888 => Validation Loss: 0.771, Validation Accuracy: 0.877
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.699 , Training Accuracy:0.913 => Validation Loss: 0.698, Validation Accuracy: 0.907
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.623 , Training Accuracy:0.914 => Validation Loss: 0.634, Validation Accuracy: 0.893
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 6
# Training Loss: 0.566 , Training Accuracy:0.913 => Validation Loss: 0.582, Validation Accuracy: 0.913
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 7
# Training Loss: 0.520 , Training Accuracy:0.916 => Validation Loss: 0.537, Validation Accuracy: 0.920
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.488 , Training Accuracy:0.913 => Validation Loss: 0.519, Validation Accuracy: 0.887
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.452 , Training Accuracy:0.922 => Validation Loss: 0.487, Validation Accuracy: 0.900
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.425 , Training Accuracy:0.914 => Validation Loss: 0.471, Validation Accuracy: 0.893
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 11
# Training Loss: 0.405 , Training Accuracy:0.922 => Validation Loss: 0.450, Validation Accuracy: 0.900
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 12
# Training Loss: 0.381 , Training Accuracy:0.921 => Validation Loss: 0.435, Validation Accuracy: 0.890
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 13
# Training Loss: 0.360 , Training Accuracy:0.921 => Validation Loss: 0.412, Validation Accuracy: 0.893
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 14
# Training Loss: 0.346 , Training Accuracy:0.929 => Validation Loss: 0.401, Validation Accuracy: 0.907
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 15
# Training Loss: 0.338 , Training Accuracy:0.922 => Validation Loss: 0.374, Validation Accuracy: 0.907
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 16
# Training Loss: 0.322 , Training Accuracy:0.926 => Validation Loss: 0.373, Validation Accuracy: 0.910
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 17
# Training Loss: 0.308 , Training Accuracy:0.931 => Validation Loss: 0.365, Validation Accuracy: 0.903
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 18
# Training Loss: 0.299 , Training Accuracy:0.939 => Validation Loss: 0.362, Validation Accuracy: 0.893
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 19
# Training Loss: 0.292 , Training Accuracy:0.934 => Validation Loss: 0.352, Validation Accuracy: 0.900
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 20
# Training Loss: 0.283 , Training Accuracy:0.936 => Validation Loss: 0.333, Validation Accuracy: 0.903
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 21
# Training Loss: 0.280 , Training Accuracy:0.942 => Validation Loss: 0.332, Validation Accuracy: 0.907
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 22
# Training Loss: 0.267 , Training Accuracy:0.941 => Validation Loss: 0.336, Validation Accuracy: 0.900
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 23
# Training Loss: 0.256 , Training Accuracy:0.944 => Validation Loss: 0.333, Validation Accuracy: 0.887
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 24
# Training Loss: 0.256 , Training Accuracy:0.946 => Validation Loss: 0.335, Validation Accuracy: 0.897
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 25
# Training Loss: 0.247 , Training Accuracy:0.946 => Validation Loss: 0.309, Validation Accuracy: 0.897
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 26
# Training Loss: 0.243 , Training Accuracy:0.944 => Validation Loss: 0.315, Validation Accuracy: 0.890
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 27
# Training Loss: 0.245 , Training Accuracy:0.934 => Validation Loss: 0.299, Validation Accuracy: 0.903
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 28
# Training Loss: 0.239 , Training Accuracy:0.946 => Validation Loss: 0.299, Validation Accuracy: 0.903
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 29
# Training Loss: 0.224 , Training Accuracy:0.938 => Validation Loss: 0.294, Validation Accuracy: 0.900
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 30
# Training Loss: 0.219 , Training Accuracy:0.948 => Validation Loss: 0.288, Validation Accuracy: 0.900
# Finished Training
# Accuracy of ./covid-19-resnet50_pretrained_last_layer-from-scratch.pt on the Test Images: 90 %
# COVID19 - recall :  1.0  precision :  0.97333336  accuracy :  0.9911111
# NORMAL - recall :  0.85714287  precision :  0.88  accuracy :  0.9111111
# PNEUMONIA - recall :  0.8666667  precision :  0.8666667  accuracy :  0.9111111
# 0.9066666666666666

# %% [markdown]
# **Questions**:
#
# 1. Elaborate on the reason to use pretrained ImageNet weights for transfer learning (instead of training from scratch).
# 2. Which transfer learning approach performs better for finetuning on our dataset? Comment on the possible reasons!
# 3. Explain the best use-cases for ImageNet pretrained weights for the two different approaches (i.e. when it is a good idea to train from scratch OR for finetuning all layers OR for finetuning last layers).

# %% [markdown]
# 1. Pretrained models contain still valuable data even if its not in the correct domain. with pretraining the model already has seen how different image features are connected and can transfer some of these "skills" to the new task.
# 2. both perform very similar - though i would prefer only training th last layer since the gradient doesnt need to be kept track f for the hole net
# 3. full pretrain - if the target data is very unsimilar to the imagenet data
#    only last layer - if the pretraining data is similar and we only need to differentiate "simple" cases
#
#    Note: i had to change the LR and Scheduler for this task because in my case the training was extremely unstable, sometimes the model collapsed and sometimes achieved good performance.

# %% [markdown]
# **Comment:** When finetuning a model it may also be beneficial to use a different learning rate and change other hyperparameters compared to training from scratch. To keep the exercise simple we do not further explore these options here. If you're interested to investigate these effects you can explore different hyperparameters at the end of the exercise.

# %% [markdown]
# ## RadImageNet
#
# A disadvantage of using ImageNet pretraining for medical images is that the pretraining data is very different to medical images. There are several efforts to build pretraining datasets for the medical image domain, for example [RadImageNet](https://www.radimagenet.com/).
# It contains a pretraining dataset made up of radiology images of a comparable size to ImageNet and provides networks that were pretrained with this dataset.
# - For more details you can check out the [RadImageNet publication](https://doi.org/10.1148/ryai.210315).
#
# Note: if you use on RadImageNet weights you will have to use the statistics below for normalization (corresponding to the image statistics of the RadImageNet dataset):
# ```python
# # Normalization: mean and standard deviation values for the pretrained weights on RadImageNet dataset
# radimagenet_mean = (0.223, 0.223, 0.223)
# radimagenet_std = (0.203, 0.203, 0.203)
# ```
#
# We now use pretrained RadImageNet weights for the ResNet50. For this we first need to get the weights (they were previously downloaded for you) and initialize the model.

# %%
# DO NOT CHANGE
radimagenet_checkpoint_path = os.path.join(model_dir, "RadImageNet_pytorch")

resnet50_ckpt = torch.load(os.path.join(radimagenet_checkpoint_path, "ResNet50.pt"), weights_only=True)

# %%
# DO NOT CHANGE
# We create the backbone to intialize it with the pretrained weights from RadImageNet
class Backbone(nn.Module):
    def __init__(self):
        super().__init__()
        base_model = torchvision.models.resnet50()
        encoder_layers = list(base_model.children())
        self.backbone = nn.Sequential(*encoder_layers[:9])
                        
    def forward(self, x):
        return self.backbone(x)


# We build the classifier to use the features for transfer learning
class Classifier(nn.Module):
    def __init__(self, num_class):
        super().__init__()
        self.drop_out = nn.Dropout()
        self.linear = nn.Linear(2048, num_class)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.drop_out(x)
        x = self.linear(x)
        return x

# %% [markdown]
# ## Architecture

# %% [markdown]
# We now combine the backbone (ResNet50 pretrained on RadImageNet) and the classification layer for our dataset.
#
# Train and evaluate this model. You can decide whether to finetune the whole model or just the last layer.

# %%
# Let's call the backbone (the encoder excluding the last layers)
backbone = Backbone()

# Loading the pretrained weights to the backbone
backbone.load_state_dict(resnet50_ckpt)

# Now let's call the expected fully connected layer
classifier = Classifier(num_class=len(classes))

# Finally, we are ready to build our model 
net = nn.Sequential(backbone, classifier).to(device)

# %%
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

from torchvision import datasets
from torch.utils.data import DataLoader

mean = (0.223, 0.223, 0.223)
std = (0.203, 0.203, 0.203)

train_dataset_mean,train_dataset_std = mean,std

transform_data_augmentation = get_transforms_augmentation(256,256)

train_dataset_augmented = datasets.ImageFolder(train_dir, transform=transform_data_augmentation)
val_dataset_augmented = datasets.ImageFolder(val_dir, transform=transform_data_augmentation)

train_dataset = datasets.ImageFolder(train_dir, transform=get_transforms(height,width))
val_dataset = datasets.ImageFolder(val_dir, transform=get_transforms(height,width))
full_train_dataset = ConcatDataset([train_dataset, train_dataset_augmented])
full_val_dataset = ConcatDataset([val_dataset, val_dataset_augmented])

# Dataloaders
train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(full_val_dataset, batch_size=batch_size, shuffle=False)



test_dataset = datasets.ImageFolder(test_dir, transform=get_transforms(height,width))


test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all / last layers, transfer learning using RadImageNet weights)
#    = (the training workflows are the same as above)



lr=0.0001
patience=30
num_epochs=30




model = net

# Train the network as usual

model_name = 'radnet_pretrained'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = None #optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)




accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-radnet_pretrained-from-scratch.pt
# Starting training from scratch with network:  radnet_pretrained
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 1
# Training Loss: 0.993 , Training Accuracy:0.509 => Validation Loss: 0.842, Validation Accuracy: 0.743
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 2
# Training Loss: 0.447 , Training Accuracy:0.888 => Validation Loss: 0.337, Validation Accuracy: 0.867
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 3
# Training Loss: 0.193 , Training Accuracy:0.944 => Validation Loss: 0.234, Validation Accuracy: 0.897
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 4
# Training Loss: 0.141 , Training Accuracy:0.950 => Validation Loss: 0.234, Validation Accuracy: 0.903
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 5
# Training Loss: 0.091 , Training Accuracy:0.970 => Validation Loss: 0.196, Validation Accuracy: 0.920
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 6
# Training Loss: 0.071 , Training Accuracy:0.974 => Validation Loss: 0.234, Validation Accuracy: 0.920
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 7
# Training Loss: 0.039 , Training Accuracy:0.989 => Validation Loss: 0.218, Validation Accuracy: 0.927
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 8
# Training Loss: 0.049 , Training Accuracy:0.988 => Validation Loss: 0.266, Validation Accuracy: 0.887
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 9
# Training Loss: 0.046 , Training Accuracy:0.981 => Validation Loss: 0.214, Validation Accuracy: 0.937
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 10
# Training Loss: 0.039 , Training Accuracy:0.987 => Validation Loss: 0.281, Validation Accuracy: 0.913
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 11
# Training Loss: 0.029 , Training Accuracy:0.987 => Validation Loss: 0.179, Validation Accuracy: 0.930
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 12
# Training Loss: 0.029 , Training Accuracy:0.992 => Validation Loss: 0.243, Validation Accuracy: 0.917
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 13
# Training Loss: 0.024 , Training Accuracy:0.992 => Validation Loss: 0.198, Validation Accuracy: 0.947
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 14
# Training Loss: 0.014 , Training Accuracy:0.998 => Validation Loss: 0.266, Validation Accuracy: 0.927
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 15
# Training Loss: 0.013 , Training Accuracy:0.996 => Validation Loss: 0.230, Validation Accuracy: 0.943
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 16
# Training Loss: 0.026 , Training Accuracy:0.989 => Validation Loss: 0.226, Validation Accuracy: 0.930
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 17
# Training Loss: 0.012 , Training Accuracy:0.997 => Validation Loss: 0.238, Validation Accuracy: 0.943
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 18
# Training Loss: 0.005 , Training Accuracy:1.000 => Validation Loss: 0.233, Validation Accuracy: 0.940
# EarlyStopping Counter: 7 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 19
# Training Loss: 0.006 , Training Accuracy:0.999 => Validation Loss: 0.236, Validation Accuracy: 0.937
# EarlyStopping Counter: 8 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 20
# Training Loss: 0.012 , Training Accuracy:0.997 => Validation Loss: 0.415, Validation Accuracy: 0.900
# EarlyStopping Counter: 9 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 21
# Training Loss: 0.024 , Training Accuracy:0.992 => Validation Loss: 0.249, Validation Accuracy: 0.947
# EarlyStopping Counter: 10 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 22
# Training Loss: 0.022 , Training Accuracy:0.994 => Validation Loss: 0.247, Validation Accuracy: 0.930
# EarlyStopping Counter: 11 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 23
# Training Loss: 0.006 , Training Accuracy:0.999 => Validation Loss: 0.243, Validation Accuracy: 0.927
# EarlyStopping Counter: 12 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 24
# Training Loss: 0.003 , Training Accuracy:1.000 => Validation Loss: 0.214, Validation Accuracy: 0.937
# EarlyStopping Counter: 13 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 25
# Training Loss: 0.004 , Training Accuracy:0.999 => Validation Loss: 0.280, Validation Accuracy: 0.930
# EarlyStopping Counter: 14 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 26
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.220, Validation Accuracy: 0.943
# EarlyStopping Counter: 15 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 27
# Training Loss: 0.005 , Training Accuracy:0.998 => Validation Loss: 0.330, Validation Accuracy: 0.930
# EarlyStopping Counter: 16 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 28
# Training Loss: 0.007 , Training Accuracy:0.998 => Validation Loss: 0.304, Validation Accuracy: 0.927
# EarlyStopping Counter: 17 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 29
# Training Loss: 0.005 , Training Accuracy:0.998 => Validation Loss: 0.285, Validation Accuracy: 0.930
# EarlyStopping Counter: 18 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 30
# Training Loss: 0.015 , Training Accuracy:0.997 => Validation Loss: 0.294, Validation Accuracy: 0.933
# EarlyStopping Counter: 19 out of 30
# Finished Training
# Accuracy of ./covid-19-radnet_pretrained-from-scratch.pt on the Test Images: 91 %
# COVID19 - recall :  0.97333336  precision :  0.97333336  accuracy :  0.9822222
# NORMAL - recall :  0.8372093  precision :  0.96  accuracy :  0.92444444
# PNEUMONIA - recall :  0.9375  precision :  0.8  accuracy :  0.91555554
# 0.9111111111111111

# %% [markdown]
# **Questions**:
#
# 1. Comment on your choice of transfer learning approach (either finetuning last layers / all layers in the model) for RadImageNet? Why could the best approach here be different from ImageNet?

# %% [markdown]
# 1. I choose to do a full training.
#    Both full pretrain and only last layer should have an increased performance since the domain ofthe data is much closer to our actual domain.
#    however since the domain is so similar i thought it should be easier for the model to adapt small changes in all layers compared to using imagenet.
#
#    Maybe a single layer would be good too to preserve the pretrained stsructure of the radnet

# %% [markdown]
# ### Overall Results:
#
# Update the table with your results for all experiments from the exercise:
#
# | Model    | Training                         | Test Accuracy |
# |:-------: |:--------------------------------:|:-------------:|
# | ResNet18 | from scratch                     |          70.666     |
# | ResNet34 | from scratch                     |         68.888     |
# | ResNet50 | from scratch                     |         77.33      |
# | ResNet50 | from scratch (with augmentation) |         88.444      |
# | ResNet50 | from ImageNet (all layers)       |        93.333       |
# | ResNet50 | from ImageNet (last layers)      |         90.666      |
# | ResNet50 | from RadImageNet                 |        91.111       |

# %% [markdown]
# **Question**:
# 1. Comment on the trend observed in the results from the table.
# 2. Which is the overall best model? Does this match your expectations? Why/why not?
#
# **Important: Please read the end of the exercise sheet and upload the predictions from your best model, also if you choose not to try out to further improve it.**

# %% [markdown]
# 1. data agumentation helps. the bigger archictectures need better data and techniques as pretraining and tend to outperform smaller models after that.
# 2. resnet50 from imagenet all layers, expected the radnet all layers to be better, maybe i should have only trained a single layer. Why, i am not sure of.

# %% [markdown]
# ## Further improve your model (*Optional*)
#
# You can now try to further improve the model by using different architectures or trying some of the advanced training and inference techniques discussed in the lecture. This part of the exercise is optional, and you can try to apply as many approaches for improving your method as you would like. If you don't want to work on the optional part at all please go to the end of the exercise to submit the predictions from your best model.
#
# Here are the aproaches you can try to improve the model:
# 1. Update the training hyperparameter:
#     - You can choose a better initial learning rate, or choose different options for the learning rate scheduler or early stopping.
#     - The most important parameter is probably the learning rate; if you want to improve it then train only for a short time and compare different values. (Remember lecture 2 and the first exercise).
# 2. Try other architectures provided in `torchvision.models`, which implements further CNN architectures (and their respective ImageNet pretrained weights). For example `DenseNet` or `EfficientNet` could yield better results than ResNets.
#     - `torchvision.models` also offers vision transformer architectures (https://arxiv.org/abs/2010.11929). We will cover those later in the lecture, but if you want you can try them here as well. See the snippet at the end of this section for details.
# 3. Try advanced data augmentation strategies, which change the data manifold severly and can boost performance. For example MixUp or CutMix. `torchivsion` already implements them, see [data augmentation with torchvision](https://pytorch.org/vision/stable/transforms.html) for details.
# 4. Try test-time data augmentation. We have covered this idea in the lecture. To use it you don't need to change the training at all, but just update the model prediction during testing. Fot this you can either update the functionality in `ex3_utils.py` or implement a wrapper function or class around the model that implements the test-time data augmentation logic.
# 5. Try model ensembling: combine the predictions of different models on the test set or use an implicit averaging approach like polyak averaging. For this approaches you may need to update the training and/or prediction functions from `ex3_utils.py`.
#
# Here's a snippet that shows how to use vision transformers from torchvision:
#
# ```python
# # replacing the respective layers of the "transformer-based networks" to match our number of classes
# net = torchvision.models.vit_b_16(pretrained=True)
# net.heads.head = nn.Linear(768, num_classes)
# net.to(device)
# ```

# %% [markdown]
# **Hint**: if you want to systematically improve your model you should proceed as follows:
# - Decide on the base architecture and how to initialize it.
#     - Either choose the best model you according to the exercise so far or try if advanced architectures from `torchvision` bring an improvement and continue with one of them.
# - Optimize the training hyperparameters (learning rate, scheduling, early stopping).
# - Investigate advanced techniques:
#   - Training with more or advanced data augmentation.
#   - Test-time data augmentation
#   - Model ensembling
#
# You can divide some of these tasks up among your group and train the best model by combining the best settings you have found for the individual steps.

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all / last layers, transfer learning using RadImageNet weights)
#    = (the training workflows are the same as above)



lr=0.001
patience=30
num_epochs=30




model = net

# Train the network as usual

model_name = 'radnet_pretrained'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)




accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-radnet_pretrained-from-scratch.pt
# Starting training from scratch with network:  radnet_pretrained
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 1
# Training Loss: 0.115 , Training Accuracy:0.961 => Validation Loss: 0.326, Validation Accuracy: 0.933
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 2
# Training Loss: 0.066 , Training Accuracy:0.979 => Validation Loss: 0.202, Validation Accuracy: 0.947
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 3
# Training Loss: 0.121 , Training Accuracy:0.957 => Validation Loss: 0.444, Validation Accuracy: 0.830
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 4
# Training Loss: 0.102 , Training Accuracy:0.963 => Validation Loss: 0.316, Validation Accuracy: 0.893
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 5
# Training Loss: 0.047 , Training Accuracy:0.980 => Validation Loss: 0.317, Validation Accuracy: 0.937
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 6
# Training Loss: 0.030 , Training Accuracy:0.988 => Validation Loss: 0.303, Validation Accuracy: 0.943
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 7
# Training Loss: 0.036 , Training Accuracy:0.987 => Validation Loss: 0.256, Validation Accuracy: 0.947
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 8
# Training Loss: 0.057 , Training Accuracy:0.980 => Validation Loss: 0.281, Validation Accuracy: 0.927
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 9
# Training Loss: 0.049 , Training Accuracy:0.984 => Validation Loss: 0.465, Validation Accuracy: 0.837
# EarlyStopping Counter: 7 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 10
# Training Loss: 0.078 , Training Accuracy:0.976 => Validation Loss: 0.261, Validation Accuracy: 0.947
# EarlyStopping Counter: 8 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 11
# Training Loss: 0.085 , Training Accuracy:0.973 => Validation Loss: 0.337, Validation Accuracy: 0.927
# EarlyStopping Counter: 9 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 12
# Training Loss: 0.058 , Training Accuracy:0.973 => Validation Loss: 0.459, Validation Accuracy: 0.940
# EarlyStopping Counter: 10 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 13
# Training Loss: 0.059 , Training Accuracy:0.982 => Validation Loss: 0.325, Validation Accuracy: 0.957
# EarlyStopping Counter: 11 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 14
# Training Loss: 0.009 , Training Accuracy:0.998 => Validation Loss: 0.303, Validation Accuracy: 0.953
# EarlyStopping Counter: 12 out of 30
# 900/900: [===============================>] - ETA 0.2s
# Epoch: 15
# Training Loss: 0.007 , Training Accuracy:0.998 => Validation Loss: 0.307, Validation Accuracy: 0.957
# EarlyStopping Counter: 13 out of 30
# 900/900: [===============================>] - ETA 0.7ss
# Epoch: 16
# Training Loss: 0.008 , Training Accuracy:0.998 => Validation Loss: 0.257, Validation Accuracy: 0.960
# EarlyStopping Counter: 14 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 17
# Training Loss: 0.007 , Training Accuracy:0.999 => Validation Loss: 0.275, Validation Accuracy: 0.950
# EarlyStopping Counter: 15 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 18
# Training Loss: 0.003 , Training Accuracy:0.999 => Validation Loss: 0.273, Validation Accuracy: 0.953
# EarlyStopping Counter: 16 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 19
# Training Loss: 0.004 , Training Accuracy:0.999 => Validation Loss: 0.254, Validation Accuracy: 0.960
# EarlyStopping Counter: 17 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 20
# Training Loss: 0.003 , Training Accuracy:0.999 => Validation Loss: 0.268, Validation Accuracy: 0.957
# EarlyStopping Counter: 18 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 21
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.262, Validation Accuracy: 0.960
# EarlyStopping Counter: 19 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 22
# Training Loss: 0.003 , Training Accuracy:0.999 => Validation Loss: 0.270, Validation Accuracy: 0.957
# EarlyStopping Counter: 20 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 23
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.282, Validation Accuracy: 0.957
# EarlyStopping Counter: 21 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 24
# Training Loss: 0.003 , Training Accuracy:0.998 => Validation Loss: 0.290, Validation Accuracy: 0.957
# EarlyStopping Counter: 22 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 25
# Training Loss: 0.002 , Training Accuracy:0.999 => Validation Loss: 0.311, Validation Accuracy: 0.953
# EarlyStopping Counter: 23 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 26
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.318, Validation Accuracy: 0.960
# EarlyStopping Counter: 24 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 27
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.305, Validation Accuracy: 0.953
# EarlyStopping Counter: 25 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 28
# Training Loss: 0.002 , Training Accuracy:0.999 => Validation Loss: 0.260, Validation Accuracy: 0.953
# EarlyStopping Counter: 26 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 29
# Training Loss: 0.001 , Training Accuracy:1.000 => Validation Loss: 0.306, Validation Accuracy: 0.957
# EarlyStopping Counter: 27 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 30
# Training Loss: 0.002 , Training Accuracy:0.999 => Validation Loss: 0.292, Validation Accuracy: 0.960
# EarlyStopping Counter: 28 out of 30
# Finished Training
# Accuracy of ./covid-19-radnet_pretrained-from-scratch.pt on the Test Images: 92 %
# COVID19 - recall :  1.0  precision :  0.9866667  accuracy :  0.9955556
# NORMAL - recall :  0.86419755  precision :  0.93333334  accuracy :  0.9288889
# PNEUMONIA - recall :  0.9142857  precision :  0.85333335  accuracy :  0.92444444
# 0.9244444444444444

# %% [markdown]
# ## Train your best model

# %%
# TODO: IMPLEMENT AND TRAIN THE BEST MODEL HERE
# resnet50 all layers with imgnet
# Batch size
batch_size = 16  # TODO: YOUR CHOICE HERE

from torchvision import datasets
from torch.utils.data import DataLoader

mean=[0.485, 0.456, 0.406] 
std=[0.229, 0.224, 0.225]

train_dataset_mean,train_dataset_std = mean,std

transform_data_augmentation = get_transforms_augmentation(256,256)

train_dataset_augmented = datasets.ImageFolder(train_dir, transform=transform_data_augmentation)
val_dataset_augmented = datasets.ImageFolder(val_dir, transform=transform_data_augmentation)

train_dataset = datasets.ImageFolder(train_dir, transform=get_transforms(height,width))
val_dataset = datasets.ImageFolder(val_dir, transform=get_transforms(height,width))
full_train_dataset = ConcatDataset([train_dataset, train_dataset_augmented])
full_val_dataset = ConcatDataset([val_dataset, val_dataset_augmented])

# Dataloaders
train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(full_val_dataset, batch_size=batch_size, shuffle=False)



test_dataset = datasets.ImageFolder(test_dir, transform=get_transforms(height,width))


test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TODO: YOUR SOLUTIONS HERE

# HINT:
#    - Training a ResNet50 (updating all the layers, transfer learning using ImageNet weights)
#    = (the training workflows are the same as above)
from torchvision.models import resnet50, ResNet50_Weights

model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)
model.fc =  nn.Linear(2048, 3)
model.to(device)

lr=0.0001
patience=30
num_epochs=30






# Train the network as usual

model_name = 'resnet50_pretrained'
checkpoint_name = f'covid-19-{model_name}-from-scratch.pt'
checkpoint_path = os.path.join(root_dir, checkpoint_name)
print("The model checkpoint will be saved here: ", checkpoint_path)

print("Starting training from scratch with network: ", model_name)

criterion = nn.CrossEntropyLoss()  # loss function
optimizer = torch.optim.AdamW(model.parameters(),lr=lr)  # optimizer
scheduler = None #optim.lr_scheduler.ReduceLROnPlateau(optimizer)

early_stopping = utils.EarlyStopping(checkpoint_path=checkpoint_path,patience=patience)




accuracy, val_accuracy, losses, val_losses = utils.run_training(train_loader, val_loader, model, num_epochs, criterion, optimizer, scheduler=scheduler, early_stopping=early_stopping, device=device)

utils.get_metric_plots(accuracy, val_accuracy, "accuracy")

utils.get_metric_plots(losses,val_losses, "loss")

model.load_state_dict(torch.load(checkpoint_path, weights_only=True))

correct, total = utils.test_evaluation(model, test_loader, device)
print(f'Accuracy of {checkpoint_path} on the Test Images: %d %%' % (100 * correct / total))
results[model_name] = 100 * correct / total

cm = utils.get_confusion_matrix(classes, test_loader,model, device)

utils.check_precision_recall_accuracy(cm, classes)

utils.visualize_confusion_matrix(cm, classes, correct, total)
# Out:
# The model checkpoint will be saved here:  ./covid-19-resnet50_pretrained-from-scratch.pt
# Starting training from scratch with network:  resnet50_pretrained
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 1
# Training Loss: 0.469 , Training Accuracy:0.907 => Validation Loss: 0.230, Validation Accuracy: 0.897
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 2
# Training Loss: 0.334 , Training Accuracy:0.887 => Validation Loss: 0.265, Validation Accuracy: 0.913
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 3
# Training Loss: 0.165 , Training Accuracy:0.944 => Validation Loss: 0.221, Validation Accuracy: 0.923
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 4
# Training Loss: 0.099 , Training Accuracy:0.964 => Validation Loss: 0.292, Validation Accuracy: 0.890
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 5
# Training Loss: 0.126 , Training Accuracy:0.957 => Validation Loss: 0.195, Validation Accuracy: 0.933
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 6
# Training Loss: 0.083 , Training Accuracy:0.967 => Validation Loss: 0.156, Validation Accuracy: 0.953
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 7
# Training Loss: 0.047 , Training Accuracy:0.987 => Validation Loss: 0.187, Validation Accuracy: 0.940
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 8
# Training Loss: 0.025 , Training Accuracy:0.991 => Validation Loss: 0.172, Validation Accuracy: 0.937
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 9
# Training Loss: 0.061 , Training Accuracy:0.981 => Validation Loss: 0.207, Validation Accuracy: 0.933
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 10
# Training Loss: 0.040 , Training Accuracy:0.987 => Validation Loss: 0.233, Validation Accuracy: 0.943
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 11
# Training Loss: 0.093 , Training Accuracy:0.966 => Validation Loss: 0.202, Validation Accuracy: 0.940
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 12
# Training Loss: 0.038 , Training Accuracy:0.983 => Validation Loss: 0.136, Validation Accuracy: 0.963
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 13
# Training Loss: 0.044 , Training Accuracy:0.983 => Validation Loss: 0.244, Validation Accuracy: 0.933
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 14
# Training Loss: 0.017 , Training Accuracy:0.993 => Validation Loss: 0.157, Validation Accuracy: 0.963
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 15
# Training Loss: 0.102 , Training Accuracy:0.970 => Validation Loss: 0.242, Validation Accuracy: 0.913
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 16
# Training Loss: 0.232 , Training Accuracy:0.919 => Validation Loss: 0.244, Validation Accuracy: 0.927
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 17
# Training Loss: 0.076 , Training Accuracy:0.973 => Validation Loss: 0.196, Validation Accuracy: 0.950
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 18
# Training Loss: 0.033 , Training Accuracy:0.991 => Validation Loss: 0.236, Validation Accuracy: 0.930
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 19
# Training Loss: 0.041 , Training Accuracy:0.986 => Validation Loss: 0.217, Validation Accuracy: 0.923
# EarlyStopping Counter: 7 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 20
# Training Loss: 0.027 , Training Accuracy:0.990 => Validation Loss: 0.277, Validation Accuracy: 0.930
# EarlyStopping Counter: 8 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 21
# Training Loss: 0.015 , Training Accuracy:0.994 => Validation Loss: 0.103, Validation Accuracy: 0.973
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 22
# Training Loss: 0.002 , Training Accuracy:1.000 => Validation Loss: 0.141, Validation Accuracy: 0.963
# EarlyStopping Counter: 1 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 23
# Training Loss: 0.032 , Training Accuracy:0.992 => Validation Loss: 0.142, Validation Accuracy: 0.953
# EarlyStopping Counter: 2 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 24
# Training Loss: 0.003 , Training Accuracy:1.000 => Validation Loss: 0.244, Validation Accuracy: 0.947
# EarlyStopping Counter: 3 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 25
# Training Loss: 0.017 , Training Accuracy:0.993 => Validation Loss: 0.357, Validation Accuracy: 0.897
# EarlyStopping Counter: 4 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 26
# Training Loss: 0.009 , Training Accuracy:0.994 => Validation Loss: 0.472, Validation Accuracy: 0.913
# EarlyStopping Counter: 5 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 27
# Training Loss: 0.029 , Training Accuracy:0.989 => Validation Loss: 0.152, Validation Accuracy: 0.943
# EarlyStopping Counter: 6 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 28
# Training Loss: 0.056 , Training Accuracy:0.979 => Validation Loss: 0.190, Validation Accuracy: 0.943
# EarlyStopping Counter: 7 out of 30
# 900/900: [===============================>] - ETA 0.3ss
# Epoch: 29
# Training Loss: 0.014 , Training Accuracy:0.996 => Validation Loss: 0.235, Validation Accuracy: 0.940
# EarlyStopping Counter: 8 out of 30
# 900/900: [===============================>] - ETA 0.2ss
# Epoch: 30
# Training Loss: 0.023 , Training Accuracy:0.990 => Validation Loss: 0.154, Validation Accuracy: 0.950
# EarlyStopping Counter: 9 out of 30
# Finished Training
# Accuracy of ./covid-19-resnet50_pretrained-from-scratch.pt on the Test Images: 93 %
# COVID19 - recall :  0.9868421  precision :  1.0  accuracy :  0.9955556
# NORMAL - recall :  0.8961039  precision :  0.92  accuracy :  0.93777776
# PNEUMONIA - recall :  0.9305556  precision :  0.8933333  accuracy :  0.94222224
# 0.9377777777777778

# %% [markdown]
# ## Submission:
#
# - The `unknown` set corresponds to a hold-out test set (with unlabeled images). Such unseen test data is common in machine learning challenges to ensure an objective comparison of different methods and to test how well these solutions would generalize to real data.
# - Submit the predictons for the `unknown` set using your best model together with your exercise solution.
#     - Upload the solutions to `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission for Homework 3` -> `Challenge Results`-> `Tutorial <X>`.
#     - Your submission should be called `results_surname1_surname2_surname3.csv`. The expected file format is described below and we provide a function that generates these results for you already.
# - **Please submit the results from your best model (or the model you expect to perform best). If you don't work on the optional part of the exercise then submit the best result from the models you have trained so far.**
#     - The group with the best submission will get a small prize ;-)
#
# ### Expected Submission Format
#
# Before submitting your results, please make sure that they are in the below mentioned format:
# - `results_<surname1>_<surname2>_<surname3>.csv`
#     - patient_\<ID-1>.jpg | \<CLASS-1>
#     - patient_\<ID-2>.jpg | \<CLASS-2> <br>
#     . <br>
#     . <br>
#     . <br>
#     - patient_\<ID_n>.jpg | \<CLASS-[1-3]>
#
# We have prepared a function that generates these predictions for you (see below).

# %%
# TODO: YOUR SOLUTION HERE
filename = "results.csv"

# Function generating predictions (in a csv file) for the respective images in the hold-out test set (`unknown` folder)
# Note: if you want to use test-time-augmentation or model ensembling you may need to update this function.
# If you don't want to update it you can also create a new class that implements a wrapper around the model(s)
# that implements the augmentation or ensembling logic.
utils.predict_unknown(model, height, width, train_dataset_mean, train_dataset_std, unknown_dir, device, filename)

# Download link is automatically generated for the final results generated
FileLink(filename)
# Out:
# /mnt/vast-standard/home/lennart.hahner/u23584/jupyterhub-gwdg/results.csv
